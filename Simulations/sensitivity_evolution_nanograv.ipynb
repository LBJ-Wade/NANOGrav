# %% [markdown]
# # Calculating $A_{\rm GWB}(t)$ for NANOGrav with `hasasia`
# #### Jeffrey S. Hazboun

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import astropy.units as u
import astropy.constants as c
import sys,os,glob,json,pickle,copy
from enterprise.pulsar import Pulsar as ePulsar

from astropy.time import Time as T

# %% [markdown]
# ## Installation
# I'm not actually sure that one needs enterprise installed if you are using a set of pickled enterprise.Pulsar objects, but let us know and we can send you installation instructions. I'm assuming most people who are looking at this already have it installed.
#
# If you need to install `hasasia` then just use:
# ```
# pip install hasasia
# ```

# %%
import hasasia.sensitivity as hsen
import hasasia.sim as hsim
import hasasia.skymap as hsky

# %% [markdown]
# Below we load a pickled list of enterprise pulsars. Making this list is the basic first step for all `enterprise` data analyses and and is included in most tutorials. Let me know if you need code to make this.

# %%
with open('./pickle_barrel/dsa2000_st_quo.pkl', 'rb') as fin:
    psrs=pickle.load(fin)

# %% [markdown]
# Here we make a list of slices to do the analysis at. This goes from 8-40 years, but if one needs to see home many years of data there are in the data set you can use
# ```Python
# hsen.get_Tspan(psrs)/(365.25*24*3600)
#
# ```

# %%
Nyears = [8.0 + ii*1.0 for ii in range(33)][::-1]

# %% [markdown]
# Set a list of amplitudes to calculate when we will reach the given SNR cutoff.
#
# __Note__: If a `d` error is raised when you run the main script then you can set the initial `A_gwb` to be slightly higher. In order for the algorithm to work the first calculation must return an SNR>3.

# %%
N_amps = 30
A_gwb = np.logspace(np.log10(1.2e-17),np.log10(1.5e-15),N_amps)

# %%
A_gwb
# Out:
# array([1.20000000e-17, 1.41738714e-17, 1.67415525e-17, 1.97743844e-17,
#        2.33566317e-17, 2.75878245e-17, 3.25855231e-17, 3.84885845e-17,
#        4.54610205e-17, 5.36965549e-17, 6.34240052e-17, 7.49136411e-17,
#        8.84846929e-17, 1.04514221e-16, 1.23447594e-16, 1.45810861e-16,
#        1.72225366e-16, 2.03425015e-16, 2.40276667e-16, 2.83804215e-16,
#        3.35217037e-16, 3.95943597e-16, 4.67671136e-16, 5.52392544e-16,
#        6.52461740e-16, 7.70659066e-16, 9.10268541e-16, 1.07516910e-15,
#        1.26994238e-15, 1.50000000e-15])

# %% [markdown]
# ## Main Script
#
# This script runs through the various amplitudes given above and, starting with the full data set, it continues to calculate SNR when a year of data is removed. When it reaches an SNR<`snr_cutoff` it then moves on to the next amplitude. It "intelligently" tries to make an educated guess of which slice to start with, as not to waste time.

# %%
results = np.zeros((N_amps,5))
curves = []
IDX = 0

# This thinning option is for using real channelized NANOGrav data.
# One does not need 55 TOAs from a given epoch to calculate the sensitivity
# Try starting with thin = 10 in that case. For simulated data sets, thin = 1 is fine. (It won't thin)
thin = 1

#Set SNR cutoff, usually 3.0
snr_cutoff = 3.0

#If rerunning this try, except gets used to delete old cutoff values. 
try:
    del old_cutoff, old_snr
except NameError:
    pass

old_pnames=[]
for jj, amp in enumerate(A_gwb):
    print('!!!Looking at A_gwb={0:1.2e}'.format(amp))
    
    # Make a new copy of the list of pickled enterprise.Pulsar objects for the new amplitude.
    psrs_copy = copy.deepcopy(psrs)
    start_mjd = np.amin([p.toas.min() for p in psrs_copy])/(24*3600)
    
    #This buffers the iterative start value so you don't skip to a value <snr_cutoff.
    if IDX == 0:
        idx_use = IDX
    else:
        idx_use = IDX - 1
        
    
    for yr in Nyears[idx_use:]:
        #Calculate the time span and frequencies for slicing
        tspan = yr*365.25*24*3600
        freqs = np.linspace(1/tspan,30/tspan,30)
        Psrs = []
        cutoff = start_mjd + yr*365.25
        print("Cutoff: ",cutoff)
        #Filter pulsars by timespan and add GWB as autocorrelated RN
        idxs = []
        for idx, ePsr in enumerate(psrs_copy):
            #Cut the data to the requested length
            ePsr.filter_data(start_time=start_mjd, end_time=cutoff)
            
            #Make a simple diagonal correlation matrix
            corr = np.diag(ePsr.toaerrs[::thin]**2)
            # Add autocorrelation noise from GWB into pulsar
            plaw = hsen.red_noise_powerlaw(A=amp, gamma=13/3., freqs=freqs)
            corr += hsen.corr_from_psd(freqs=freqs, psd=plaw,
                                  toas=ePsr.toas[::thin])
            
            #Make hasasia.Pulsar object
            psr = hsen.Pulsar(toas=ePsr.toas[::thin],
                              toaerrs=ePsr.toaerrs[::thin],
                              phi=ePsr.phi,theta=ePsr.theta,
                              designmatrix=ePsr.Mmat[::thin,:],
                              N=corr)
            #Keep the name 
            psr.name = ePsr.name
            
            #If there are no TOAs remaining, or the time span of the pulsar is <3 cut.
            if (psr.toas.size ==0) or (hsen.get_Tspan([psr]) < 3*365.25*24*3600):
                idxs.append(idx)
                pass
            else:
                Psrs.append(psr)
            
            print('\rAdd PSR {0} complete '.format(ePsr.name),
                  end='',flush=True)
            
        # Get the list of pulsars before the cut
        pnames = [p.name for p in Psrs]
        
        #Remove pulsars with less than 3 years of data
        for idx in reversed(idxs):
            del psrs_copy[idx]
        
        # List number of pulsars that made the cut
        print('. --> {0} Pulsars'.format(len(Psrs)))
        
        # These help in debugging if needed. 
#         if len(old_pnames) < len(pnames):
#             print([nm for nm in old_pnames if nm not in pnames])
#         old_pnames = pnames   
        
        # Make the individual hasasia.Spectrum objects
        spectra = []
        for p in Psrs:
            sp = hsen.Spectrum(p, freqs=freqs)
            sp.NcalInv #This line is what takes most of the computation time.
            spectra.append(sp)
            print('\rSpectra for PSR {0} complete '.format(p.name),
                  end='', flush=True)
        
        # Calculate the stochastic sensitivity curve
        curv = hsen.GWBSensitivityCurve(spectra)
        
        # Make a power-law spectrum using the given amplitude and calculate the SNR
        Sh = hsen.S_h(amp, -2/3. ,freqs)
        snr = curv.SNR(Sh)
        
        if snr < snr_cutoff:
            try: # This will only work if there is an old SNR
                results[jj,:] = amp,cutoff,snr,old_cutoff,old_snr
            except NameError:
                if IDX == 0:
                    err_msg = 'Initial A_GWB={0:1.2e} too low!!'.format(amp)
                    err_msg += '\nReturns SNR={0:1.2f}.'.format(snr)
                    err_msg += '\nMust enter a higher value for lowest A_GWB value'
                    raise ValueError(err_msg)
                else:
                    IDX = Nyears.index(yr) - 1
                    break
            curves.append(curv)
            IDX = Nyears.index(yr)
            print('\n***Year {0} complete. SNR={1:1.2f}'.format(yr,snr))
            print('\n')
            break
        else:
            old_cutoff = cutoff
            old_snr = snr
            print('\n***Year {0} complete. SNR={1:1.2f}'.format(yr,snr))
        
    try:
        del old_cutoff, old_snr
    except NameError:
        pass
# Out:
# !!!Looking at A_gwb=1.20e-17
# Cutoff:  67980.99543677893
# Add PSR J2322+2057 complete . --> 157 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 40.0 complete. SNR=3.19
# Cutoff:  67615.74543677893
# Add PSR J2322+2057 complete . --> 157 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 39.0 complete. SNR=2.92
#
#
# !!!Looking at A_gwb=1.42e-17
# Cutoff:  67980.99543677893
# Add PSR J2322+2057 complete . --> 157 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 40.0 complete. SNR=3.79
# Cutoff:  67615.74543677893
# Add PSR J2322+2057 complete . --> 157 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 39.0 complete. SNR=3.47
# Cutoff:  67250.49543677893
# Add PSR J2322+2057 complete . --> 155 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 38.0 complete. SNR=3.17
# Cutoff:  66885.24543677893
# Add PSR J2322+2057 complete . --> 150 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 37.0 complete. SNR=2.89
#
#
# !!!Looking at A_gwb=1.67e-17
# Cutoff:  67250.49543677893
# Add PSR J2322+2057 complete . --> 155 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 38.0 complete. SNR=3.76
# Cutoff:  66885.24543677893
# Add PSR J2322+2057 complete . --> 150 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 37.0 complete. SNR=3.43
# Cutoff:  66519.99543677893
# Add PSR J2322+2057 complete . --> 149 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 36.0 complete. SNR=3.12
# Cutoff:  66154.74543677893
# Add PSR J2322+2057 complete . --> 141 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 35.0 complete. SNR=2.82
#
#
# !!!Looking at A_gwb=1.98e-17
# Cutoff:  66519.99543677893
# Add PSR J2322+2057 complete . --> 149 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 36.0 complete. SNR=3.68
# Cutoff:  66154.74543677893
# Add PSR J2322+2057 complete . --> 141 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 35.0 complete. SNR=3.34
# Cutoff:  65789.49543677893
# Add PSR J2322+2057 complete . --> 141 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 34.0 complete. SNR=3.02
# Cutoff:  65424.24543677893
# Add PSR J2322+2057 complete . --> 136 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 33.0 complete. SNR=2.72
#
#
# !!!Looking at A_gwb=2.34e-17
# Cutoff:  65789.49543677893
# Add PSR J2322+2057 complete . --> 141 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 34.0 complete. SNR=3.56
# Cutoff:  65424.24543677893
# Add PSR J2322+2057 complete . --> 136 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 33.0 complete. SNR=3.21
# Cutoff:  65058.99543677893
# Add PSR J2322+2057 complete . --> 133 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 32.0 complete. SNR=2.88
#
#
# !!!Looking at A_gwb=2.76e-17
# Cutoff:  65424.24543677893
# Add PSR J2322+2057 complete . --> 136 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 33.0 complete. SNR=3.77
# Cutoff:  65058.99543677893
# Add PSR J2322+2057 complete . --> 133 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 32.0 complete. SNR=3.39
# Cutoff:  64693.74543677893
# Add PSR J2322+2057 complete . --> 125 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 31.0 complete. SNR=3.04
# Cutoff:  64328.49543677893
# Add PSR J2322+2057 complete . --> 125 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 30.0 complete. SNR=2.71
#
#
# !!!Looking at A_gwb=3.26e-17
# Cutoff:  64693.74543677893
# Add PSR J2322+2057 complete . --> 125 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 31.0 complete. SNR=3.56
# Cutoff:  64328.49543677893
# Add PSR J2322+2057 complete . --> 125 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 30.0 complete. SNR=3.18
# Cutoff:  63963.24543677893
# Add PSR J2322+2057 complete . --> 121 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 29.0 complete. SNR=2.83
#
#
# !!!Looking at A_gwb=3.85e-17
# Cutoff:  64328.49543677893
# Add PSR J2322+2057 complete . --> 125 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 30.0 complete. SNR=3.72
# Cutoff:  63963.24543677893
# Add PSR J2322+2057 complete . --> 121 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 29.0 complete. SNR=3.31
# Cutoff:  63597.99543677893
# Add PSR J2322+2057 complete . --> 116 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 28.0 complete. SNR=2.93
#
#
# !!!Looking at A_gwb=4.55e-17
# Cutoff:  63963.24543677893
# Add PSR J2322+2057 complete . --> 121 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 29.0 complete. SNR=3.85
# Cutoff:  63597.99543677893
# Add PSR J2322+2057 complete . --> 116 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 28.0 complete. SNR=3.42
# Cutoff:  63232.74543677893
# Add PSR J2322+2057 complete . --> 109 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 27.0 complete. SNR=3.02
# Cutoff:  62867.49543677893
# Add PSR J2322+2057 complete . --> 108 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 26.0 complete. SNR=2.66
#
#
# !!!Looking at A_gwb=5.37e-17
# Cutoff:  63232.74543677893
# Add PSR J2322+2057 complete . --> 109 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 27.0 complete. SNR=3.51
# Cutoff:  62867.49543677893
# Add PSR J2322+2057 complete . --> 108 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 26.0 complete. SNR=3.10
# Cutoff:  62502.24543677893
# Add PSR J2322+2057 complete . --> 104 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 25.0 complete. SNR=2.71
#
#
# !!!Looking at A_gwb=6.34e-17
# Cutoff:  62867.49543677893
# Add PSR J2322+2057 complete . --> 108 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 26.0 complete. SNR=3.59
# Cutoff:  62502.24543677893
# Add PSR J2322+2057 complete . --> 104 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 25.0 complete. SNR=3.15
# Cutoff:  62136.99543677893
# Add PSR J2322+2057 complete . --> 101 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 24.0 complete. SNR=2.75
#
#
# !!!Looking at A_gwb=7.49e-17
# Cutoff:  62502.24543677893
# Add PSR J2322+2057 complete . --> 104 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 25.0 complete. SNR=3.64
# Cutoff:  62136.99543677893
# Add PSR J2322+2057 complete . --> 101 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 24.0 complete. SNR=3.19
# Cutoff:  61771.74543677893
# Add PSR J2322+2057 complete . --> 93 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 23.0 complete. SNR=2.77
#
#
# !!!Looking at A_gwb=8.85e-17
# Cutoff:  62136.99543677893
# Add PSR J2322+2057 complete . --> 101 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 24.0 complete. SNR=3.67
# Cutoff:  61771.74543677893
# Add PSR J2322+2057 complete . --> 93 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 23.0 complete. SNR=3.20
# Cutoff:  61406.49543677893
# Add PSR J2322+2057 complete . --> 91 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 22.0 complete. SNR=2.74
#
#
# !!!Looking at A_gwb=1.05e-16
# Cutoff:  61771.74543677893
# Add PSR J2322+2057 complete . --> 93 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 23.0 complete. SNR=3.67
# Cutoff:  61406.49543677893
# Add PSR J2322+2057 complete . --> 91 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 22.0 complete. SNR=3.16
# Cutoff:  61041.24543677893
# Add PSR J2322+2057 complete . --> 87 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 21.0 complete. SNR=2.69
#
#
# !!!Looking at A_gwb=1.23e-16
# Cutoff:  61406.49543677893
# Add PSR J2322+2057 complete . --> 91 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 22.0 complete. SNR=3.62
# Cutoff:  61041.24543677893
# Add PSR J2322+2057 complete . --> 87 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 21.0 complete. SNR=3.09
# Cutoff:  60675.99543677893
# Add PSR J2322+2057 complete . --> 84 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 20.0 complete. SNR=2.64
#
#
# !!!Looking at A_gwb=1.46e-16
# Cutoff:  61041.24543677893
# Add PSR J2322+2057 complete . --> 87 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 21.0 complete. SNR=3.53
# Cutoff:  60675.99543677893
# Add PSR J2322+2057 complete . --> 84 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 20.0 complete. SNR=3.03
# Cutoff:  60310.74543677893
# Add PSR J2322+2057 complete . --> 78 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 19.0 complete. SNR=2.59
#
#
# !!!Looking at A_gwb=1.72e-16
# Cutoff:  60675.99543677893
# Add PSR J2322+2057 complete . --> 84 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 20.0 complete. SNR=3.46
# Cutoff:  60310.74543677893
# Add PSR J2322+2057 complete . --> 78 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 19.0 complete. SNR=2.97
#
#
# !!!Looking at A_gwb=2.03e-16
# Cutoff:  60675.99543677893
# Add PSR J2322+2057 complete . --> 84 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 20.0 complete. SNR=3.92
# Cutoff:  60310.74543677893
# Add PSR J2322+2057 complete . --> 78 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 19.0 complete. SNR=3.37
# Cutoff:  59945.49543677893
# Add PSR J2322+2057 complete . --> 76 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 18.0 complete. SNR=2.87
#
#
# !!!Looking at A_gwb=2.40e-16
# Cutoff:  60310.74543677893
# Add PSR J2322+2057 complete . --> 78 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 19.0 complete. SNR=3.82
# Cutoff:  59945.49543677893
# Add PSR J2322+2057 complete . --> 76 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 18.0 complete. SNR=3.26
# Cutoff:  59580.24543677893
# Add PSR J2322+2057 complete . --> 72 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 17.0 complete. SNR=2.72
#
#
# !!!Looking at A_gwb=2.84e-16
# Cutoff:  59945.49543677893
# Add PSR J2322+2057 complete . --> 76 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 18.0 complete. SNR=3.68
# Cutoff:  59580.24543677893
# Add PSR J2322+2057 complete . --> 72 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 17.0 complete. SNR=3.09
# Cutoff:  59214.99543677893
# Add PSR J2322+2057 complete . --> 69 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 16.0 complete. SNR=2.54
#
#
# !!!Looking at A_gwb=3.35e-16
# Cutoff:  59580.24543677893
# Add PSR J2322+2057 complete . --> 72 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 17.0 complete. SNR=3.50
# Cutoff:  59214.99543677893
# Add PSR J2322+2057 complete . --> 69 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 16.0 complete. SNR=2.88
#
#
# !!!Looking at A_gwb=3.96e-16
# Cutoff:  59580.24543677893
# Add PSR J2322+2057 complete . --> 72 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 17.0 complete. SNR=3.93
# Cutoff:  59214.99543677893
# Add PSR J2322+2057 complete . --> 69 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 16.0 complete. SNR=3.24
# Cutoff:  58849.74543677893
# Add PSR J2322+2057 complete . --> 54 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 15.0 complete. SNR=2.66
#
#
# !!!Looking at A_gwb=4.68e-16
# Cutoff:  59214.99543677893
# Add PSR J2322+2057 complete . --> 69 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 16.0 complete. SNR=3.64
# Cutoff:  58849.74543677893
# Add PSR J2322+2057 complete . --> 54 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 15.0 complete. SNR=3.00
# Cutoff:  58484.49543677893
# Add PSR J2322+2057 complete . --> 53 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 14.0 complete. SNR=2.54
#
#
# !!!Looking at A_gwb=5.52e-16
# Cutoff:  58849.74543677893
# Add PSR J2322+2057 complete . --> 54 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 15.0 complete. SNR=3.37
# Cutoff:  58484.49543677893
# Add PSR J2322+2057 complete . --> 53 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 14.0 complete. SNR=2.85
#
#
# !!!Looking at A_gwb=6.52e-16
# Cutoff:  58849.74543677893
# Add PSR J2322+2057 complete . --> 54 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 15.0 complete. SNR=3.76
# Cutoff:  58484.49543677893
# Add PSR J2322+2057 complete . --> 53 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 14.0 complete. SNR=3.20
# Cutoff:  58119.24543677893
# Add PSR J2322+2057 complete . --> 46 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 13.0 complete. SNR=2.69
#
#
# !!!Looking at A_gwb=7.71e-16
# Cutoff:  58484.49543677893
# Add PSR J2322+2057 complete . --> 53 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 14.0 complete. SNR=3.56
# Cutoff:  58119.24543677893
# Add PSR J2322+2057 complete . --> 46 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 13.0 complete. SNR=3.01
# Cutoff:  57753.99543677893
# Add PSR J2322+2057 complete . --> 42 Pulsars
# Spectra for PSR J2317+1439 complete
# ***Year 12.0 complete. SNR=2.50
#
#
# !!!Looking at A_gwb=9.10e-16
# Cutoff:  58119.24543677893
# Add PSR J2322+2057 complete . --> 46 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 13.0 complete. SNR=3.35
# Cutoff:  57753.99543677893
# Add PSR J2322+2057 complete . --> 42 Pulsars
# Spectra for PSR J2317+1439 complete
# ***Year 12.0 complete. SNR=2.80
#
#
# !!!Looking at A_gwb=1.08e-15
# Cutoff:  58119.24543677893
# Add PSR J2322+2057 complete . --> 46 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 13.0 complete. SNR=3.72
# Cutoff:  57753.99543677893
# Add PSR J2322+2057 complete . --> 42 Pulsars
# Spectra for PSR J2317+1439 complete
# ***Year 12.0 complete. SNR=3.12
# Cutoff:  57388.74543677893
# Add PSR J2317+1439 complete . --> 33 Pulsars
# Spectra for PSR J2317+1439 complete
# ***Year 11.0 complete. SNR=2.55
#
#
# !!!Looking at A_gwb=1.27e-15
# Cutoff:  57753.99543677893
# Add PSR J2322+2057 complete . --> 42 Pulsars
# Spectra for PSR J2317+1439 complete
# ***Year 12.0 complete. SNR=3.45
# Cutoff:  57388.74543677893
# Add PSR J2317+1439 complete . --> 33 Pulsars
# Spectra for PSR J2317+1439 complete
# ***Year 11.0 complete. SNR=2.84
#
#
# !!!Looking at A_gwb=1.50e-15
# Cutoff:  57753.99543677893
# Add PSR J2322+2057 complete . --> 42 Pulsars
# Spectra for PSR J2317+1439 complete
# ***Year 12.0 complete. SNR=3.81
# Cutoff:  57388.74543677893
# Add PSR J2317+1439 complete . --> 33 Pulsars
# Spectra for PSR J2317+1439 complete
# ***Year 11.0 complete. SNR=3.14
# Cutoff:  57023.49543677893
# Add PSR J2317+1439 complete . --> 33 Pulsars
# Spectra for PSR J2317+1439 complete
# ***Year 10.0 complete. SNR=2.54

# %%
# We keep all of the sensitivity curves as a visual check
# Note that the frequency coverage of the 30 frequencies changes over time. 
for curv in curves:
    plt.loglog(curv.freqs,curv.h_c)
    
# plt.ylim(4e-16,1e-15)
plt.show()

# %% [markdown]
# Here we do a linear interpolation by hand to calculate when the threshold on the SNR is crossed. If for some reason the plot below isn't smooth enough, one could use a finer set of years at which to slice.

# %%
time_detection = []
for row in results:
    x1,y1 = row[[1,2]]
    x2,y2 = row[[3,4]]
    m = (y2-y1)/(x2-x1)
    x = (3-y1)/m
    time_detection.append([x+x1,row[0]])
    
time_detection = np.array(time_detection)

# %%
plt.semilogy(time_detection[:,0],time_detection[:,1])
plt.grid(which='both')
plt.show()

# %% [markdown]
# Save the file to a text file if you wish.

# %%
# np.savetxt('dsa2000_190520_status_quo_sens_curv.txt',
#            np.array((yrs[::-1],time_detection[:,1][::-1])).T,
#            fmt='%4.3f, %1.2e')

# %%
# stat=np.loadtxt('dsa2000_190520_status_quo_sens_curv.txt',delimiter=',')

# %% [markdown]
# Below are the red noise values for the pulsars that were found to have significant amounts of red noise in the 11-year data paper.

# %%
rn_psrs = {'B1855+09':[10**-13.7707, 3.6081],
           'B1937+21':[10**-13.2393, 2.46521],
           'J0030+0451':[10**-14.0649, 4.15366],
           'J0613-0200':[10**-13.1403, 1.24571],
           'J1012+5307':[10**-12.6833, 0.975424],
           'J1643-1224':[10**-12.245, 1.32361],
           'J1713+0747':[10**-14.3746, 3.06793],
           'J1747-4036':[10**-12.2165, 1.40842],
           'J1903+0327':[10**-12.2461, 2.16108],
           'J1909-3744':[10**-13.9429, 2.38219],
           'J2145-0750':[10**-12.6893, 1.32307],
           }

# %% [markdown]
# Here the best guess for the smallest amplitude is a bit bigger since we are injecting red noise. I have iterated on this particular data set, so I knew what to put. The code will error if you haven't gone high enough. If you go too low the first amplitude might take a bit longer, but it will be faster after that.

# %%
A_gwb2 = np.logspace(np.log10(1.5e-17),np.log10(1.5e-15),N_amps)

# %% [markdown]
# There is only one small difference in this code where the red noise from above is injected on top of the GWB.

# %%
results2 = np.zeros((N_amps,5))
curves2 = []
IDX = 0

# This thinning option is for using real channelized NANOGrav data.
# One does not need 55 TOAs from a given epoch to calculate the sensitivity
# Try starting with thin = 10 in that case. For simulated data sets, thin = 1 is fine. (It won't thin)
thin = 1

#Set SNR cutoff, usually 3.0
snr_cutoff = 3.0

#If rerunning this try, except gets used to delete old cutoff values. 
try:
    del old_cutoff, old_snr
except NameError:
    pass

old_pnames=[]
for jj, amp in enumerate(A_gwb2):
    print('!!!Looking at A_gwb={0:1.2e}'.format(amp))
    
    # Make a new copy of the list of pickled enterprise.Pulsar objects for the new amplitude.
    psrs_copy = copy.deepcopy(psrs)
    start_mjd = np.amin([p.toas.min() for p in psrs_copy])/(24*3600)
    
    #This buffers the iterative start value so you don't skip to a value <snr_cutoff.
    if IDX == 0:
        idx_use = IDX
    else:
        idx_use = IDX - 1
        
    
    for yr in Nyears[idx_use:]:
        #Calculate the time span and frequencies for slicing
        tspan = yr*365.25*24*3600
        freqs = np.linspace(1/tspan,30/tspan,30)
        Psrs = []
        cutoff = start_mjd + yr*365.25
        print("Cutoff: ",cutoff)
        #Filter pulsars by timespan and add GWB as autocorrelated RN
        idxs = []
        for idx, ePsr in enumerate(psrs_copy):
            #Cut the data to the requested length
            ePsr.filter_data(start_time=start_mjd, end_time=cutoff)
            
            #Make a simple diagonal correlation matrix
            corr = np.diag(ePsr.toaerrs[::thin]**2)
            # Add autocorrelation noise from GWB into pulsar
            plaw = hsen.red_noise_powerlaw(A=amp, gamma=13/3., freqs=freqs)
            corr += hsen.corr_from_psd(freqs=freqs, psd=plaw,
                                  toas=ePsr.toas[::thin])
            
            #!!!!! Only main difference between the scripts !!!!!!
            # Add RN to the pulsars that are in the list from the 11-year data paper
            if ePsr.name in rn_psrs.keys():
                Amp, gam = rn_psrs[ePsr.name]
                plaw = hsen.red_noise_powerlaw(A=Amp, gamma=gam, freqs=freqs)
                corr += hsen.corr_from_psd(freqs=freqs, psd=plaw,
                                           toas=ePsr.toas[::thin])
            
            #Make hasasia.Pulsar object
            psr = hsen.Pulsar(toas=ePsr.toas[::thin],
                              toaerrs=ePsr.toaerrs[::thin],
                              phi=ePsr.phi,theta=ePsr.theta,
                              designmatrix=ePsr.Mmat[::thin,:],
                              N=corr)
            #Keep the name 
            psr.name = ePsr.name
            
            #If there are no TOAs remaining, or the time span of the pulsar is <3 cut.
            if (psr.toas.size ==0) or (hsen.get_Tspan([psr]) < 3*365.25*24*3600):
                idxs.append(idx)
                pass
            else:
                Psrs.append(psr)
            
            print('\rAdd PSR {0} complete '.format(ePsr.name),
                  end='',flush=True)
            
        # Get the list of pulsars before the cut
        pnames = [p.name for p in Psrs]
        
        #Remove pulsars with less than 3 years of data
        for idx in reversed(idxs):
            del psrs_copy[idx]
        
        # List number of pulsars that made the cut
        print('. --> {0} Pulsars'.format(len(Psrs)))
        
        # These help in debugging if needed. 
#         if len(old_pnames) < len(pnames):
#             print([nm for nm in old_pnames if nm not in pnames])
#         old_pnames = pnames   
        
        # Make the individual hasasia.Spectrum objects
        spectra = []
        for p in Psrs:
            sp = hsen.Spectrum(p, freqs=freqs)
            sp.NcalInv #This line is what takes most of the computation time.
            spectra.append(sp)
            print('\rSpectra for PSR {0} complete '.format(p.name),
                  end='', flush=True)
        
        # Calculate the stochastic sensitivity curve
        curv = hsen.GWBSensitivityCurve(spectra)
        
        # Make a power-law spectrum using the given amplitude and calculate the SNR
        Sh = hsen.S_h(amp, -2/3. ,freqs)
        snr = curv.SNR(Sh)
        
        if snr < snr_cutoff:
            try: # This will only work if there is an old SNR
                results2[jj,:] = amp,cutoff,snr,old_cutoff,old_snr
            except NameError:
                if IDX == 0:
                    err_msg = 'Initial A_GWB={0:1.2e} too low!!'.format(amp)
                    err_msg += '\nReturns SNR={0:1.2f}.'.format(snr)
                    err_msg += '\nMust enter a higher value for lowest A_GWB value'
                    raise ValueError(err_msg)
                else:
                    IDX = Nyears.index(yr) - 1
                    break
            curves2.append(curv)
            IDX = Nyears.index(yr)
            print('\n***Year {0} complete. SNR={1:1.2f}'.format(yr,snr))
            print('\n')
            break
        else:
            old_cutoff = cutoff
            old_snr = snr
            print('\n***Year {0} complete. SNR={1:1.2f}'.format(yr,snr))
        
    try:
        del old_cutoff, old_snr
    except NameError:
        pass
# Out:
# !!!Looking at A_gwb=1.50e-17
# Cutoff:  67980.99543677893
# Add PSR J2322+2057 complete . --> 157 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 40.0 complete. SNR=3.18
# Cutoff:  67615.74543677893
# Add PSR J2322+2057 complete . --> 157 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 39.0 complete. SNR=2.88
#
#
# !!!Looking at A_gwb=1.76e-17
# Cutoff:  67980.99543677893
# Add PSR J2322+2057 complete . --> 157 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 40.0 complete. SNR=3.78
# Cutoff:  67615.74543677893
# Add PSR J2322+2057 complete . --> 157 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 39.0 complete. SNR=3.43
# Cutoff:  67250.49543677893
# Add PSR J2322+2057 complete . --> 155 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 38.0 complete. SNR=3.10
# Cutoff:  66885.24543677893
# Add PSR J2322+2057 complete . --> 150 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 37.0 complete. SNR=2.79
#
#
# !!!Looking at A_gwb=2.06e-17
# Cutoff:  67250.49543677893
# Add PSR J2322+2057 complete . --> 155 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 38.0 complete. SNR=3.67
# Cutoff:  66885.24543677893
# Add PSR J2322+2057 complete . --> 150 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 37.0 complete. SNR=3.31
# Cutoff:  66519.99543677893
# Add PSR J2322+2057 complete . --> 149 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 36.0 complete. SNR=2.98
#
#
# !!!Looking at A_gwb=2.42e-17
# Cutoff:  66885.24543677893
# Add PSR J2322+2057 complete . --> 150 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 37.0 complete. SNR=3.91
# Cutoff:  66519.99543677893
# Add PSR J2322+2057 complete . --> 149 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 36.0 complete. SNR=3.52
# Cutoff:  66154.74543677893
# Add PSR J2322+2057 complete . --> 141 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 35.0 complete. SNR=3.16
# Cutoff:  65789.49543677893
# Add PSR J2322+2057 complete . --> 141 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 34.0 complete. SNR=2.82
#
#
# !!!Looking at A_gwb=2.83e-17
# Cutoff:  66154.74543677893
# Add PSR J2322+2057 complete . --> 141 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 35.0 complete. SNR=3.72
# Cutoff:  65789.49543677893
# Add PSR J2322+2057 complete . --> 141 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 34.0 complete. SNR=3.33
# Cutoff:  65424.24543677893
# Add PSR J2322+2057 complete . --> 136 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 33.0 complete. SNR=2.96
#
#
# !!!Looking at A_gwb=3.32e-17
# Cutoff:  65789.49543677893
# Add PSR J2322+2057 complete . --> 141 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 34.0 complete. SNR=3.90
# Cutoff:  65424.24543677893
# Add PSR J2322+2057 complete . --> 136 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 33.0 complete. SNR=3.48
# Cutoff:  65058.99543677893
# Add PSR J2322+2057 complete . --> 133 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 32.0 complete. SNR=3.09
# Cutoff:  64693.74543677893
# Add PSR J2322+2057 complete . --> 125 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 31.0 complete. SNR=2.73
#
#
# !!!Looking at A_gwb=3.89e-17
# Cutoff:  65058.99543677893
# Add PSR J2322+2057 complete . --> 133 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 32.0 complete. SNR=3.62
# Cutoff:  64693.74543677893
# Add PSR J2322+2057 complete . --> 125 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 31.0 complete. SNR=3.21
# Cutoff:  64328.49543677893
# Add PSR J2322+2057 complete . --> 125 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 30.0 complete. SNR=2.82
#
#
# !!!Looking at A_gwb=4.56e-17
# Cutoff:  64693.74543677893
# Add PSR J2322+2057 complete . --> 125 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 31.0 complete. SNR=3.74
# Cutoff:  64328.49543677893
# Add PSR J2322+2057 complete . --> 125 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 30.0 complete. SNR=3.30
# Cutoff:  63963.24543677893
# Add PSR J2322+2057 complete . --> 121 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 29.0 complete. SNR=2.89
#
#
# !!!Looking at A_gwb=5.34e-17
# Cutoff:  64328.49543677893
# Add PSR J2322+2057 complete . --> 125 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 30.0 complete. SNR=3.84
# Cutoff:  63963.24543677893
# Add PSR J2322+2057 complete . --> 121 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 29.0 complete. SNR=3.38
# Cutoff:  63597.99543677893
# Add PSR J2322+2057 complete . --> 116 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 28.0 complete. SNR=2.94
#
#
# !!!Looking at A_gwb=6.26e-17
# Cutoff:  63963.24543677893
# Add PSR J2322+2057 complete . --> 121 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 29.0 complete. SNR=3.91
# Cutoff:  63597.99543677893
# Add PSR J2322+2057 complete . --> 116 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 28.0 complete. SNR=3.43
# Cutoff:  63232.74543677893
# Add PSR J2322+2057 complete . --> 109 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 27.0 complete. SNR=2.98
#
#
# !!!Looking at A_gwb=7.34e-17
# Cutoff:  63597.99543677893
# Add PSR J2322+2057 complete . --> 116 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 28.0 complete. SNR=3.96
# Cutoff:  63232.74543677893
# Add PSR J2322+2057 complete . --> 109 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 27.0 complete. SNR=3.46
# Cutoff:  62867.49543677893
# Add PSR J2322+2057 complete . --> 108 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 26.0 complete. SNR=2.99
#
#
# !!!Looking at A_gwb=8.60e-17
# Cutoff:  63232.74543677893
# Add PSR J2322+2057 complete . --> 109 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 27.0 complete. SNR=3.98
# Cutoff:  62867.49543677893
# Add PSR J2322+2057 complete . --> 108 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 26.0 complete. SNR=3.46
# Cutoff:  62502.24543677893
# Add PSR J2322+2057 complete . --> 104 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 25.0 complete. SNR=2.98
#
#
# !!!Looking at A_gwb=1.01e-16
# Cutoff:  62867.49543677893
# Add PSR J2322+2057 complete . --> 108 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 26.0 complete. SNR=3.98
# Cutoff:  62502.24543677893
# Add PSR J2322+2057 complete . --> 104 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 25.0 complete. SNR=3.44
# Cutoff:  62136.99543677893
# Add PSR J2322+2057 complete . --> 101 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 24.0 complete. SNR=2.96
#
#
# !!!Looking at A_gwb=1.18e-16
# Cutoff:  62502.24543677893
# Add PSR J2322+2057 complete . --> 104 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 25.0 complete. SNR=3.95
# Cutoff:  62136.99543677893
# Add PSR J2322+2057 complete . --> 101 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 24.0 complete. SNR=3.41
# Cutoff:  61771.74543677893
# Add PSR J2322+2057 complete . --> 93 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 23.0 complete. SNR=2.91
#
#
# !!!Looking at A_gwb=1.39e-16
# Cutoff:  62136.99543677893
# Add PSR J2322+2057 complete . --> 101 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 24.0 complete. SNR=3.90
# Cutoff:  61771.74543677893
# Add PSR J2322+2057 complete . --> 93 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 23.0 complete. SNR=3.34
# Cutoff:  61406.49543677893
# Add PSR J2322+2057 complete . --> 91 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 22.0 complete. SNR=2.82
#
#
# !!!Looking at A_gwb=1.62e-16
# Cutoff:  61771.74543677893
# Add PSR J2322+2057 complete . --> 93 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 23.0 complete. SNR=3.82
# Cutoff:  61406.49543677893
# Add PSR J2322+2057 complete . --> 91 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 22.0 complete. SNR=3.24
# Cutoff:  61041.24543677893
# Add PSR J2322+2057 complete . --> 87 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 21.0 complete. SNR=2.68
#
#
# !!!Looking at A_gwb=1.90e-16
# Cutoff:  61406.49543677893
# Add PSR J2322+2057 complete . --> 91 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 22.0 complete. SNR=3.69
# Cutoff:  61041.24543677893
# Add PSR J2322+2057 complete . --> 87 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 21.0 complete. SNR=3.07
# Cutoff:  60675.99543677893
# Add PSR J2322+2057 complete . --> 84 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 20.0 complete. SNR=2.57
#
#
# !!!Looking at A_gwb=2.23e-16
# Cutoff:  61041.24543677893
# Add PSR J2322+2057 complete . --> 87 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 21.0 complete. SNR=3.50
# Cutoff:  60675.99543677893
# Add PSR J2322+2057 complete . --> 84 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 20.0 complete. SNR=2.95
#
#
# !!!Looking at A_gwb=2.61e-16
# Cutoff:  61041.24543677893
# Add PSR J2322+2057 complete . --> 87 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 21.0 complete. SNR=3.97
# Cutoff:  60675.99543677893
# Add PSR J2322+2057 complete . --> 84 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 20.0 complete. SNR=3.36
# Cutoff:  60310.74543677893
# Add PSR J2322+2057 complete . --> 78 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 19.0 complete. SNR=2.81
#
#
# !!!Looking at A_gwb=3.07e-16
# Cutoff:  60675.99543677893
# Add PSR J2322+2057 complete . --> 84 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 20.0 complete. SNR=3.80
# Cutoff:  60310.74543677893
# Add PSR J2322+2057 complete . --> 78 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 19.0 complete. SNR=3.20
# Cutoff:  59945.49543677893
# Add PSR J2322+2057 complete . --> 76 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 18.0 complete. SNR=2.65
#
#
# !!!Looking at A_gwb=3.59e-16
# Cutoff:  60310.74543677893
# Add PSR J2322+2057 complete . --> 78 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 19.0 complete. SNR=3.62
# Cutoff:  59945.49543677893
# Add PSR J2322+2057 complete . --> 76 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 18.0 complete. SNR=3.02
# Cutoff:  59580.24543677893
# Add PSR J2322+2057 complete . --> 72 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 17.0 complete. SNR=2.45
#
#
# !!!Looking at A_gwb=4.21e-16
# Cutoff:  59945.49543677893
# Add PSR J2322+2057 complete . --> 76 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 18.0 complete. SNR=3.42
# Cutoff:  59580.24543677893
# Add PSR J2322+2057 complete . --> 72 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 17.0 complete. SNR=2.80
#
#
# !!!Looking at A_gwb=4.94e-16
# Cutoff:  59945.49543677893
# Add PSR J2322+2057 complete . --> 76 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 18.0 complete. SNR=3.85
# Cutoff:  59580.24543677893
# Add PSR J2322+2057 complete . --> 72 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 17.0 complete. SNR=3.17
# Cutoff:  59214.99543677893
# Add PSR J2322+2057 complete . --> 69 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 16.0 complete. SNR=2.51
#
#
# !!!Looking at A_gwb=5.78e-16
# Cutoff:  59580.24543677893
# Add PSR J2322+2057 complete . --> 72 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 17.0 complete. SNR=3.58
# Cutoff:  59214.99543677893
# Add PSR J2322+2057 complete . --> 69 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 16.0 complete. SNR=2.85
#
#
# !!!Looking at A_gwb=6.78e-16
# Cutoff:  59580.24543677893
# Add PSR J2322+2057 complete . --> 72 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 17.0 complete. SNR=4.01
# Cutoff:  59214.99543677893
# Add PSR J2322+2057 complete . --> 69 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 16.0 complete. SNR=3.22
# Cutoff:  58849.74543677893
# Add PSR J2322+2057 complete . --> 54 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 15.0 complete. SNR=2.56
#
#
# !!!Looking at A_gwb=7.95e-16
# Cutoff:  59214.99543677893
# Add PSR J2322+2057 complete . --> 69 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 16.0 complete. SNR=3.62
# Cutoff:  58849.74543677893
# Add PSR J2322+2057 complete . --> 54 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 15.0 complete. SNR=2.90
#
#
# !!!Looking at A_gwb=9.32e-16
# Cutoff:  59214.99543677893
# Add PSR J2322+2057 complete . --> 69 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 16.0 complete. SNR=4.05
# Cutoff:  58849.74543677893
# Add PSR J2322+2057 complete . --> 54 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 15.0 complete. SNR=3.26
# Cutoff:  58484.49543677893
# Add PSR J2322+2057 complete . --> 53 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 14.0 complete. SNR=2.69
#
#
# !!!Looking at A_gwb=1.09e-15
# Cutoff:  58849.74543677893
# Add PSR J2322+2057 complete . --> 54 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 15.0 complete. SNR=3.65
# Cutoff:  58484.49543677893
# Add PSR J2322+2057 complete . --> 53 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 14.0 complete. SNR=3.03
# Cutoff:  58119.24543677893
# Add PSR J2322+2057 complete . --> 46 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 13.0 complete. SNR=2.49
#
#
# !!!Looking at A_gwb=1.28e-15
# Cutoff:  58484.49543677893
# Add PSR J2322+2057 complete . --> 53 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 14.0 complete. SNR=3.39
# Cutoff:  58119.24543677893
# Add PSR J2322+2057 complete . --> 46 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 13.0 complete. SNR=2.80
#
#
# !!!Looking at A_gwb=1.50e-15
# Cutoff:  58484.49543677893
# Add PSR J2322+2057 complete . --> 53 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 14.0 complete. SNR=3.78
# Cutoff:  58119.24543677893
# Add PSR J2322+2057 complete . --> 46 Pulsars
# Spectra for PSR J2322+2057 complete
# ***Year 13.0 complete. SNR=3.14
# Cutoff:  57753.99543677893
# Add PSR J2322+2057 complete . --> 42 Pulsars
# Spectra for PSR J2317+1439 complete
# ***Year 12.0 complete. SNR=2.57

# %%
time_detection2 = []
for row in results2:
    x1,y1 = row[[1,2]]
    x2,y2 = row[[3,4]]
    m = (y2-y1)/(x2-x1)
    x = (3-y1)/m
    time_detection2.append([x+x1,row[0]])
    
time_detection2 = np.array(time_detection2)

# %%
plt.semilogy(time_detection[:,0],time_detection[:,1])
plt.semilogy(time_detection2[:,0],time_detection2[:,1])
plt.show()

# %%
mjd = start_mjd + np.array(Nyears)*365.25
yrs_mjd = T(time_detection[:,0],format='mjd')
yrs=yrs_mjd.decimalyear
yrs_mjd2 = T(time_detection2[:,0],format='mjd')
yrs2=yrs_mjd2.decimalyear
# Out:
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 19 of "dubious year (Note 5)" [astropy._erfa.core]
# WARNING: astropy: ErfaWarning: ERFA function "d2dtf" yielded 19 of "dubious year (Note 5)"
# WARNING: ErfaWarning: ERFA function "dtf2d" yielded 19 of "dubious year (Note 6)" [astropy._erfa.core]
# WARNING: astropy: ErfaWarning: ERFA function "dtf2d" yielded 19 of "dubious year (Note 6)"
# WARNING: ErfaWarning: ERFA function "dtf2d" yielded 21 of "dubious year (Note 6)" [astropy._erfa.core]
# WARNING: astropy: ErfaWarning: ERFA function "dtf2d" yielded 21 of "dubious year (Note 6)"
# WARNING: ErfaWarning: ERFA function "d2dtf" yielded 22 of "dubious year (Note 5)" [astropy._erfa.core]
# WARNING: astropy: ErfaWarning: ERFA function "d2dtf" yielded 22 of "dubious year (Note 5)"
# WARNING: ErfaWarning: ERFA function "dtf2d" yielded 22 of "dubious year (Note 6)" [astropy._erfa.core]
# WARNING: astropy: ErfaWarning: ERFA function "dtf2d" yielded 22 of "dubious year (Note 6)"
# WARNING: ErfaWarning: ERFA function "dtf2d" yielded 24 of "dubious year (Note 6)" [astropy._erfa.core]
# WARNING: astropy: ErfaWarning: ERFA function "dtf2d" yielded 24 of "dubious year (Note 6)"

# %%
# np.savetxt('dsa2000_190520_status_quo_sens_curv_wRN.txt',
#            np.array((yrs4[::-1],time_detection4[:,1][::-1])).T,
#            fmt='%4.3f %1.2e')

# %%
plt.semilogy(yrs, time_detection[:,1],label='Status Quo')
plt.semilogy(yrs2, time_detection2[:,1],label='Status Quo w/ RN',
             linestyle='-',color='C1')
plt.title('Amplitude Needed for an SNR of 3')
plt.grid(which='both')
# plt.xlim(2015,2040)
# plt.ylim(9e-17,2e-15)
plt.rc('text', usetex=True)
plt.ylabel('Year')
plt.ylabel(r'$A_{\rm GWB}$')
plt.legend(loc='upper right')
# plt.savefig('./amplitude_time_NG.pdf',bbox='tight',dpi=400)
plt.show()
