# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import sys,os,glob,json,pickle
from collections import OrderedDict
import scipy.interpolate as interp

import libstempo as T2
import libstempo.toasim as LT
import libstempo.plot as LP

import enterprise
from enterprise.pulsar import Pulsar

import astropy.units as u
from astropy.time import Time
from astropy.stats import LombScargle

# %%
current_path = os.getcwd()
splt_path = current_path.split("/")
top_path_idx = splt_path.index('NANOGrav')
top_directory = "/".join(splt_path[0:top_path_idx+1])

sys.path.insert(0,top_directory)

import my_toasim as MyT
import toasim as LTTest

# %%
#Where the enterprise 11yr datafiles are
current_dir = os.getcwd()
splt_path = current_dir.split("/")
top_path_idx = splt_path.index('BackgroundInjections')
top_dir = "/".join(splt_path[0:top_path_idx+1])

parpath = top_dir + '/FakePTA/'
timpath = top_dir + '/FakePTA/'

noisepath = top_dir + '/nano11/noisefiles_new/'

# %%
print('##############################################################')
print('Injections in: ', current_dir)
print('##############################################################')
print('\n')
# Out:
# ##############################################################
# Injections in:  /Users/andrewkaiser/Documents/GradSchool/Research/NANOGrav/BackgroundInjections/toasim_testing
# ##############################################################

# %%
def get_noise_from_pal2(noisefile):
    psrname = noisefile.split('/')[-1].split('_noise.txt')[0]
    fin = open(noisefile, 'r')
    lines = fin.readlines()
    params = {}
    for line in lines:
        ln = line.split()
        if 'efac' in line:
            par = 'efac'
            flag = ln[0].split('efac-')[-1]
        elif 'equad' in line:
            par = 'log10_equad'
            flag = ln[0].split('equad-')[-1]
        elif 'jitter_q' in line:
            par = 'log10_ecorr'
            flag = ln[0].split('jitter_q-')[-1]
        elif 'RN-Amplitude' in line:
            par = 'red_noise_log10_A'
            flag = ''
        elif 'RN-spectral-index' in line:
            par = 'red_noise_gamma'
            flag = ''
        else:
            break
        if flag:
            name = [psrname, flag, par]
        else:
            name = [psrname, par]
        pname = '_'.join(name)
        params.update({pname: float(ln[1])})
    return params

# %% [markdown]
# Load par, tim, and noisefiles for Fake psrs

# %%
parfiles = sorted(glob.glob(parpath+'*.par'))
timfiles = sorted(glob.glob(timpath+'*.tim'))

noisefiles = sorted(glob.glob(noisepath+'*.txt'))

psrlist = [x.split('/')[-1].split('.')[0].split('_')[0] for x in parfiles]
#timfiles = [x for x in timfiles if x.split('/')[-1].split('.')[0].split('_')[0] in psrlist]
noisefiles = [x for x in noisefiles if x.split('/')[-1].split('_')[0] in psrlist]

# %%
noise_params = {}
for nf in noisefiles:
    noise_params.update(get_noise_from_pal2(nf))

# %%
#Now parse this large dictionary so that we can call noise parameters as noise_dict[pulsar name][noise type]
#Returns either floats or 2 column arrays of flags and values. 

noise_dict = {}
for p in psrlist:
    noise_dict[p]={}
    noise_dict[p]['equads'] = []
    noise_dict[p]['efacs'] = []
    noise_dict[p]['ecorrs'] = []
    for ky in list(noise_params.keys()):
        if p in ky:
            if 'equad' in ky:
                noise_dict[p]['equads'].append([ky.replace(p + '_' , ''), noise_params[ky]])
            if 'efac' in ky:
                noise_dict[p]['efacs'].append([ky.replace(p + '_' , ''), noise_params[ky]])
            if 'ecorr' in ky:
                noise_dict[p]['ecorrs'].append([ky.replace(p + '_' , ''), noise_params[ky]])
            if 'gamma' in ky:
                noise_dict[p]['RN_gamma'] = noise_params[ky]
            if 'log10_A' in ky:
                noise_dict[p]['RN_Amp'] = 10**noise_params[ky]
                
    noise_dict[p]['equads'] = np.array(noise_dict[p]['equads'])
    noise_dict[p]['efacs'] = np.array(noise_dict[p]['efacs'])
    noise_dict[p]['ecorrs'] = np.array(noise_dict[p]['ecorrs'])    
    
    if len(noise_dict[p]['ecorrs'])==0: #Easier to just delete these dictionary items if no ECORR values. 
        noise_dict[p].__delitem__('ecorrs')

# %%
#######################################
# PASSING THROUGH TEMPO2 VIA libstempo
#######################################

t2psr = []
for ii in range(len(parfiles)):
    
    t2psr.append( T2.tempopulsar(parfile = parfiles[ii], timfile = timfiles[ii],
                                 maxobs=30000, ephem='DE436') )

    print('\r{0} of {1}'.format(ii+1,len(parfiles)),flush=True,end='')
# Out:
# 36 of 36

# %%
#By using seeds we can  reproduce the dataset if need be. 
seed_efac = 1066
seed_equad = 1492
seed_jitter = 1776
seed_red = 1987
seed_gwb_1 = 1667
seed_gwb_2 = 1980

# %% [markdown]
# Make test pulsar

# %%
orig_psr = t2psr[0]
test_psr1 = T2.tempopulsar(parfile = parfiles[0], timfile = timfiles[0],
                                 maxobs=30000, ephem='DE436')
test_psr2 = T2.tempopulsar(parfile = parfiles[0], timfile = timfiles[0],
                                 maxobs=30000, ephem='DE436')
test_psr3 = T2.tempopulsar(parfile = parfiles[0], timfile = timfiles[0],
                                 maxobs=30000, ephem='DE436')

# %% [markdown]
# # Look at Initial Residuals

# %%
LP.plotres(orig_psr)

# %% [markdown]
# ### Inject Rednoise via usual libstempo

# %%
## add red noise
LTTest.add_rednoise(test_psr1, noise_dict[test_psr1.name]['RN_Amp'], noise_dict[test_psr1.name]['RN_gamma'], 
                components = 30, seed = seed_red)

# %%
LP.plotres(test_psr1)

# %% [markdown]
# ### Inject Rednoise in linspace (same as usual way)

# %%
f_red_test_psr2,A_red_test_psr2 = MyT.add_rednoise(test_psr2, noise_dict[test_psr2.name]['RN_Amp'], noise_dict[test_psr2.name]['RN_gamma'], 
                components = 30, seed = seed_red)

# %%
LP.plotres(test_psr2)

# %% [markdown]
# ### Inject Rednoise in logspace

# %%
f_red_test_psr3,A_red_test_psr3 = MyT.add_rednoise(test_psr3, noise_dict[test_psr3.name]['RN_Amp'], noise_dict[test_psr3.name]['RN_gamma'], 
                components = 30, seed = seed_red,logspacing=True)

# %%
LP.plotres(test_psr3)

# %% [markdown]
# ### Plotting Residuals (Stripped down libstempo way)

# %%
def getpsrparams(psr):
    res, t, errs = psr.residuals(), psr.toas(), psr.toaerrs
    meanres = np.sqrt(np.mean(res**2)) / 1e-6
    return res,t,errs,meanres

# %%
res_1,t_1,errs_1,meanres_1 = getpsrparams(test_psr1)
i_1 = np.argsort(t_1)

res_2,t_2,errs_2,meanres_2 = getpsrparams(test_psr2)
i_2 = np.argsort(t_2)

res_3,t_3,errs_3,meanres_3 = getpsrparams(test_psr3)
i_3 = np.argsort(t_3)

res_4,t_4,errs_4,meanres_4 = getpsrparams(orig_psr)
i_4 = np.argsort(t_4)

# %% [markdown]
# #### Injected Rednoise Residual Comparisons

# %%
fig,(ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(20,5))
ax1.errorbar(t_1[i_1],res_1[i_1]/1e-6,yerr=errs_1[i_1],fmt='x')
ax1.set_title("libstempo res = {0:.2f} us".format(meanres_1))
ax1.set_ylabel('res [us]')

ax2.errorbar(t_2[i_2],res_2[i_2]/1e-6,yerr=errs_2[i_2],fmt='x')
ax2.set_title("linspace inject: res = {0:.2f} us".format(meanres_2))

ax3.errorbar(t_3[i_3],res_3[i_3]/1e-6,yerr=errs_3[i_3],fmt='x')
ax3.set_title("logspace inject: res = {0:.2f} us".format(meanres_3))
ax3.set_xlabel('MJD')
ax3.set_ylabel('res [us]')

ax4.errorbar(t_4[i_4],res_4[i_4]/1e-6,yerr=errs_1[i_4],fmt='x')
ax4.set_title("No inject: res = {0:.2f} us".format(meanres_4))
ax4.set_xlabel('MJD')


fig.suptitle(orig_psr.name)
#fig1.savefig(current_dir+'/Figs'+'/red_residual_comp_fakes_1.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Frequency injection/Amplitude Comparison for rednoise Injection

# %%
plt.loglog(f_red_test_psr2/u.yr.to('s'),A_red_test_psr2,'.')
plt.loglog(f_red_test_psr3/u.yr.to('s'),A_red_test_psr3,'.')
plt.xlabel(r'$f$',fontsize=13)
plt.ylabel('Injected Amplitude',fontsize=13)
#plt.savefig(current_dir+'/Figs'+'/red_noise_injection_freq_comp.pdf')
plt.show()

# %% [markdown]
# # Set up of 3 pulsar array for testing cases

# %%
#making test ptas
npsrs = 3
test_pta_1 = []
test_pta_2 = []
test_pta_3 = []
test_pta_4 = []
test_pta_5 = []

for ii in range(npsrs):
    test_pta_1.append( T2.tempopulsar(parfile = parfiles[ii], timfile = timfiles[ii],
                                 maxobs=30000, ephem='DE436'))
    test_pta_2.append( T2.tempopulsar(parfile = parfiles[ii], timfile = timfiles[ii],
                                 maxobs=30000, ephem='DE436'))
    test_pta_3.append( T2.tempopulsar(parfile = parfiles[ii], timfile = timfiles[ii],
                                 maxobs=30000, ephem='DE436'))
    test_pta_4.append( T2.tempopulsar(parfile = parfiles[ii], timfile = timfiles[ii],
                                 maxobs=30000, ephem='DE436'))
    test_pta_5.append( T2.tempopulsar(parfile = parfiles[ii], timfile = timfiles[ii],
                                 maxobs=30000, ephem='DE436'))
                 
    print('\r{0} of {1}'.format(ii+1,npsrs),flush=True,end='')
# Out:
# 3 of 3

# %% [markdown]
# # Injections of background with createGWB

# %% [markdown]
# #### Usual libstempo injection

# %%
LTTest.createGWB(test_pta_1, Amp=1.3e-15, gam=13./3., seed=seed_gwb_1, noCorr=True)

# %% [markdown]
# #### Inject GWB in linspace first way (should be same as above)

# %%
f_GWB_test_pta2,Amp_GWB_test_pta2,Res_f2 = MyT.createGWB(test_pta_2, Amp=1.3e-15, gam=13./3.,\
                                                  seed=seed_gwb_1, noCorr=True)
# Out:
# T =  15.009130075528201801
# T =  14.990948594649208199
# T =  14.994347423043389425
# dur =  473824923.27148878854
# dur =  15.014605777102466237
# f[0] =  2.1104841701774037103e-10
# f[-1] =  6.3293420263620337275e-07

# %% [markdown]
# #### Inject GWB in logspace first way

# %%
f_GWB_test_pta3,Amp_GWB_test_pta3,Res_f3 = MyT.createGWB(test_pta_3, Amp=1.3e-15, gam=13./3.,\
                                                  seed=seed_gwb_1, noCorr=True, logspacing=True,nfreqs=400)
# Out:
# T =  15.009130075528201801
# T =  14.990948594649208199
# T =  14.994347423043389425
# dur =  473824923.27148878854
# dur =  15.014605777102466237
# f[0] =  2.1104841701774017565e-10
# f[-1] =  6.3314525105322072774e-07

# %% [markdown]
# #### Inject GWB in linspace 2nd way

# %%
f_GWB_test_pta4,Amp_GWB_test_pta4,Res_f4 = MyT.my_createGWB(test_pta_4, Amp=1.3e-15, gam=13./3.,\
                                                  seed=seed_gwb_1, noCorr=True, logspacing=False)
# Out:
# dur =  473652123.27148878854
# f[0] =  2.1112541269593721947e-10
# f[-1] =  6.331651126751157212e-07
# len(f) =  3000

# %% [markdown]
# #### Inject GWB in logspace 2nd way

# %%
f_GWB_test_pta5,Amp_GWB_test_pta5,Res_f5 = MyT.my_createGWB(test_pta_5, Amp=1.3e-15, gam=13./3.,\
                                                  seed=seed_gwb_1, noCorr=True, logspacing=True)
# Out:
# dur =  473652123.27148878854
# f[0] =  2.1112541269593704747e-10
# f[-1] =  6.333762380878113064e-07
# len(f) =  3000

# %% [markdown]
# # Two different ways of calulating Powerlaw for comparison

# %%
def Plaw(f, log10_A, gamma, components):
    #From enterprise
    f = f*u.Hz
    df = np.diff(np.concatenate((np.array([0])*u.Hz, f[::components])))
    print('df[4] = ',df[4],', df[5] = ',df[5],'\n')
    if df[1] == 0.0:
        df[1] = df[0]
    else:
        df[0] = df[1]
    fyr = 1/u.yr.to('s')*u.Hz
    return ((10**log10_A)**2 / 12.0 / np.pi**2 * fyr**(gamma-3) * f**(-gamma) * np.repeat(df, components))

# %%
def Plaw_2(f, Amp, gam,dur=15.,howml=10.):
    #From libstempo
    dur = dur*u.yr.to('s')*u.s
    print('1/howml*dur = ',1/(howml*dur),'\n')
    f = f*u.Hz
    f1yr = 1/u.yr.to('s')*u.Hz
    alpha = -0.5 * (gam-3)
    hcf = Amp * (f/f1yr)**(alpha)
    C = 1 / 96 / np.pi**2 * hcf**2 / f**3 / dur / howml
    return C

# %% [markdown]
# #### Using above to construct powerlaws

# %%
Amp = 1.3e-15
gamma = 13./3.
log10_A = np.log10(Amp)
Amp_enterprise_plaw_1 = Plaw(f_GWB_test_pta2, log10_A=log10_A, gamma=gamma, components=1)
print('Amp_enterprise_plaw_1 units = ',Amp_enterprise_plaw_1.unit) 
Amp_enterprise_plaw_2 = Plaw(f_GWB_test_pta3, log10_A=log10_A, gamma=gamma, components=1)
print('Amp_enterprise_plaw_2 units = ',Amp_enterprise_plaw_2.unit) 
Amp_enterprise_plaw_3 = Plaw_2(f_GWB_test_pta4, Amp=Amp,gam=gamma)
print('Amp_enterprise_plaw_3 units = ',Amp_enterprise_plaw_3.unit) 
Amp_enterprise_plaw_4= Plaw_2(f_GWB_test_pta5,Amp=Amp,gam=gamma)
print('Amp_enterprise_plaw_4 units = ',Amp_enterprise_plaw_4.unit)
# Out:
# df[4] =  2.1104841701774038e-10 , df[5] =  2.1104841701774038e-10
#
# Amp_enterprise_plaw_1 units =  1 / Hz(10133099161583617/3377699720527872)
# df[4] =  4.543108172160715e-12 , df[5] =  4.635191347589816e-12
#
# Amp_enterprise_plaw_2 units =  1 / Hz(10133099161583617/3377699720527872)
# 1/howml*dur =  2.1125391876019301e-10 1 / s
#
# Amp_enterprise_plaw_3 units =  1 / (Hz3 s)
# 1/howml*dur =  2.1125391876019301e-10 1 / s
#
# Amp_enterprise_plaw_4 units =  1 / (Hz3 s)

# %% [markdown]
# ### Fake Injection Comparisons from power law calculations

# %%
linewidth = 4
plt.plot(f_GWB_test_pta2,Amp_enterprise_plaw_1,label='Amp_enterprise_plaw_1',linewidth=linewidth,color='b')
plt.plot(f_GWB_test_pta3,Amp_enterprise_plaw_2,label='Amp_enterprise_plaw_2',linewidth=linewidth,color='k')
plt.plot(f_GWB_test_pta4,Amp_enterprise_plaw_3,label='Amp_enterprise_plaw_3',linewidth=linewidth,color='r')
plt.plot(f_GWB_test_pta5,Amp_enterprise_plaw_4,label='Amp_enterprise_plaw_4',linewidth=linewidth,color='c')
plt.yscale('log')
plt.xscale('log')
plt.xlabel(r'$f$',fontsize=12)
plt.ylabel('Injection Amplitude',fontsize=14)
plt.legend(loc='upper right',fontsize=10)
#plt.savefig(current_dir+'/Figs'+'/red_noise_injection_freq_comp.pdf')
plt.show()

# %%
print(np.sum(Amp_enterprise_plaw_1.value))

print(np.sum(Amp_enterprise_plaw_2.value))
print(np.sum(Amp_enterprise_plaw_3.value))

print(np.sum(Amp_enterprise_plaw_4.value))
# Out:
# 5.2731199565350150127e-10
# 7.860385557389544803e-11
# 6.587397715830013859e-11
# 2.776737598757305203e-09

# %%
plt.plot(f_GWB_test_pta2,'.')
plt.plot(f_GWB_test_pta3,'.')
plt.plot(f_GWB_test_pta4,'.')
plt.plot(f_GWB_test_pta5,'.')
plt.yscale('log')

# %% [markdown]
# ### Comparison of libstempo and first way of injections

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
plt.suptitle('createGWB',fontsize=15)

ax1.loglog(f_GWB_test_pta2,Amp_GWB_test_pta2,'.')
ax1.set_title('linspace createGWB')
ax1.set_xlabel(r'$f$',fontsize=12)
ax1.set_ylabel('Injection Amplitude',fontsize=14)

ax2.loglog(f_GWB_test_pta3,Amp_GWB_test_pta3,'.')
ax2.set_title('logspace createGWB')
ax2.set_xlabel(r'$f$',fontsize=12)

ax3.loglog(f_GWB_test_pta2,Amp_GWB_test_pta2,'.')
ax3.loglog(f_GWB_test_pta3,Amp_GWB_test_pta3,'.')
ax3.set_title('logspace createGWB')
ax3.set_xlabel(r'$f$',fontsize=12)

#fig2.savefig(current_dir+'/Figs'+'/createGWB_fake_freq_comp_1.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Comparison of libstempo and second way of injections

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
plt.suptitle('my_createGWB',fontsize=15)

ax1.loglog(f_GWB_test_pta4,Amp_GWB_test_pta4,'.')
ax1.set_title('linspace createGWB')
ax1.set_xlabel(r'$f$',fontsize=12)
ax1.set_ylabel('Injection Amplitude',fontsize=14)

ax2.loglog(f_GWB_test_pta5,Amp_GWB_test_pta5,'.')
ax2.set_title('logspace createGWB')
ax2.set_xlabel(r'$f$',fontsize=12)

ax3.loglog(f_GWB_test_pta4,Amp_GWB_test_pta4,'.')
ax3.loglog(f_GWB_test_pta5,Amp_GWB_test_pta5,'.')
ax3.set_title('logspace createGWB')
ax3.set_xlabel(r'$f$',fontsize=12)

#fig2.savefig(current_dir+'/Figs'+'/createGWB_fake_freq_comp_1.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Real Injection Comparisons

# %%
linewidth=4
plt.plot(f_GWB_test_pta2,Amp_GWB_test_pta2,'.',label='Amp_GWB_test_pta2',linewidth=linewidth,color='b')
plt.plot(f_GWB_test_pta3,Amp_GWB_test_pta3,label='Amp_GWB_test_pta3',linewidth=linewidth,color='k')
plt.plot(f_GWB_test_pta4,Amp_GWB_test_pta4,label='Amp_GWB_test_pta4',linewidth=linewidth,color='r')
plt.plot(f_GWB_test_pta5,Amp_GWB_test_pta5,label='Amp_GWB_test_pta5',linewidth=linewidth,color='c')
plt.yscale('log')
plt.xscale('log')
plt.xlabel(r'$f$',fontsize=12)
plt.ylabel('Injection Amplitude',fontsize=14)
plt.legend(loc='upper right',fontsize=11)
#plt.savefig(current_dir+'/Figs'+'/red_noise_injection_freq_comp.pdf')
plt.show()

# %% [markdown]
# # Looking at frequency residuals from injections

# %% [markdown]
# #### Injections the First Way

# %%
psridx = 0
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
plt.suptitle('createGWB res_f')

ax1.loglog(f_GWB_test_pta2,Res_f2[psridx],'.')
ax1.set_xlabel(r'$f$',fontsize=14)
ax1.set_ylabel('Injection Amplitude',fontsize=14)

ax2.loglog(f_GWB_test_pta3,Res_f3[psridx],'.')
ax2.set_xlabel(r'$f$',fontsize=14)

ax3.loglog(f_GWB_test_pta2,Res_f2[psridx],'x')
ax3.loglog(f_GWB_test_pta3,Res_f3[psridx],'.')
ax3.set_xlabel(r'$f$',fontsize=14)

#fig.savefig(current_dir+'/Figs'+'/createGWB_fake_freq_residuals_1.pdf',bbox_inches='tight')
plt.show()
# Out:
# /Users/andrewkaiser/anaconda3/envs/enterprise/lib/python3.6/site-packages/numpy/core/numeric.py:501: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# #### Injections the Second Way

# %%
print(np.shape(Res_f4[0][::2]))
print(np.shape(Res_f4[0]))
# Out:
# (1500,)
# (3000,)

# %%
psridx = 0
components = 2
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
plt.suptitle('my_createGWB res_f')

ax1.loglog(f_GWB_test_pta4,Res_f4[psridx],'.')
ax1.set_xlabel(r'$f$',fontsize=14)
ax1.set_ylabel('Injection Amplitude',fontsize=14)

ax2.loglog(f_GWB_test_pta5,Res_f5[psridx],'.')
ax2.set_xlabel(r'$f$',fontsize=14)

ax3.loglog(f_GWB_test_pta4,Res_f4[psridx],'x')
ax3.loglog(f_GWB_test_pta5,Res_f5[psridx],'.')
ax3.set_xlabel(r'$f$',fontsize=14)

#fig.savefig(current_dir+'/Figs'+'/createGWB_fake_freq_residuals_1.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# # Fourier Transform on injected frequency residuals

# %%
def FFT_injection(pta,Res_f,npts=600):
    day = u.day.to('s')*u.s
    
    start = np.min([p.toas().min()*day for p in pta])
    stop = np.max([p.toas().max()*day for p in pta])
    
    # duration of the signal
    dur = (stop - start)*u.s #Time span in seconds

    # time resolution in seconds
    dt = dur/npts

    # make a vector of evenly sampled data points in seconds
    ut = np.linspace(start, stop, npts)*u.s
    
    ### injection residuals in the frequency domain
    [Npulsars,Nf] = np.shape(Res_f)

    # Now fill in bins after Nyquist (for fft data packing) and take inverse FT
    Res_f2 = np.zeros((Npulsars, 2*Nf-2), complex)    
    Res_t = np.zeros((Npulsars, 2*Nf-2))
    
    Res_f2[:,0:Nf] = Res_f[:,0:Nf]
    Res_f2[:, Nf:(2*Nf-2)] = np.conj(Res_f[:,(Nf-2):0:-1])
    
    Res_t = np.real(np.fft.ifft(Res_f2))

    # shorten data and interpolate onto ut
    Res = np.zeros((Npulsars, npts))
    res_gw = []
    for ll in range(Npulsars):
        Res[ll,:] = Res_t[ll, 10:(npts+10)]
        f = interp.interp1d(ut, Res[ll,:], kind='linear')
        res_gw.append(f(ut))
        
    return ut,res_gw

# %%
# Now fill in bins after Nyquist (for fft data packing) and take inverse FT
t2,Res_t2 = FFT_injection(test_pta_2,Res_f2)
t3,Res_t3 = FFT_injection(test_pta_3,Res_f3)
t4,Res_t4 = FFT_injection(test_pta_4,Res_f4)
t5,Res_t5 = FFT_injection(test_pta_4,Res_f5)

# %%
print(t4.unit)
#print(Res_t4[0].unit)
# Out:
# s

# %%
psridx = 0
fig,((ax1,ax2,ax3),(ax4,ax5,ax6)) = plt.subplots(2,3,figsize=(15,10))
ax1.errorbar(t2,Res_t2[psridx])
ax1.set_title('linear inject')
ax1.set_ylabel('residuals')
ax1.set_xlabel('time')

ax2.errorbar(t3,Res_t3[psridx])
ax2.set_title('log inject')
ax2.set_xlabel('time')

ax3.errorbar(t2,Res_t2[psridx])
ax3.errorbar(t3,Res_t3[psridx])
ax3.set_title('Comparison')
ax3.set_xlabel('time')

ax4.errorbar(t4,Res_t4[psridx])
ax4.set_title('linear inject')
ax4.set_ylabel('residuals')
ax4.set_xlabel('time')

ax5.errorbar(t5,Res_t5[psridx])
ax5.set_title('log inject')
ax5.set_xlabel('time')

ax6.errorbar(t4,Res_t4[psridx])
ax6.errorbar(t5,Res_t5[psridx])
ax6.set_title('Comparison')
ax6.set_xlabel('time')
plt.show()

# %% [markdown]
# # Final Residuals with injections

# %%
res_1,t_1,errs_1,meanres_1 = getpsrparams(test_pta_1[0])
i_1 = np.argsort(t_1)

res_2,t_2,errs_2,meanres_2 = getpsrparams(test_pta_2[0])
i_2 = np.argsort(t_2)

res_3,t_3,errs_3,meanres_3 = getpsrparams(test_pta_3[0])
i_3 = np.argsort(t_3)

res_4,t_4,errs_4,meanres_4 = getpsrparams(test_pta_4[0])
i_4 = np.argsort(t_4)

res_5,t_5,errs_5,meanres_5 = getpsrparams(test_pta_5[0])
i_5 = np.argsort(t_5)

# %% [markdown]
# ### Injections the First Way

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
ax1.errorbar(t_1[i_1],res_1[i_1]/1e-6,yerr=errs_1[i_1],fmt='x')
ax1.set_title("libstempo res = {0:.2f} us".format(meanres_1))
ax1.set_ylabel('res [us]')

ax2.errorbar(t_2[i_2],res_2[i_2]/1e-6,yerr=errs_2[i_2],fmt='x')
ax2.set_title("linspace inject: res = {0:.2f} us".format(meanres_2))

ax3.errorbar(t_3[i_3],res_3[i_3]/1e-6,yerr=errs_3[i_3],fmt='x')
ax3.set_title("logspace inject: res = {0:.2f} us".format(meanres_3))
ax3.set_xlabel('MJD')

fig.suptitle(test_pta_1[0].name)
#fig1.savefig(current_dir+'/Figs'+'/createGWB_fake_residual_comp_1.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Injections the Second Way

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
ax1.errorbar(t_1[i_1],res_1[i_1]/1e-6,yerr=errs_1[i_1],fmt='x')
ax1.set_title("libstempo res = {0:.2f} us".format(meanres_1))
ax1.set_ylabel('res [us]')

ax2.errorbar(t_4[i_4],res_4[i_4]/1e-6,yerr=errs_4[i_4],fmt='x')
ax2.set_title("linspace inject: res = {0:.2f} us".format(meanres_4))

ax3.errorbar(t_5[i_5],res_5[i_5]/1e-6,yerr=errs_5[i_5],fmt='x')
ax3.set_title("logspace inject: res = {0:.2f} us".format(meanres_5))
ax3.set_xlabel('MJD')

fig.suptitle(test_pta_1[0].name)
#fig1.savefig(current_dir+'/Figs'+'/createGWB_fake_residual_comp_1.pdf',bbox_inches='tight')
plt.show()

# %% [markdown]
# # Fourier transforms on residuals

# %%
psridx = 0

# %%
fft_test_pta_2 = np.fft.fft(test_pta_2[psridx].residuals().astype(float))
fft_test_pta_3 = np.fft.fft(test_pta_3[psridx].residuals().astype(float))

# %%
#Lomb Scargle FFT
#Toas in seconds
toas_test_pta_1 = test_pta_1[psridx].toas().astype(float)*u.d.to('s')
res_test_pta_1 = test_pta_1[psridx].residuals().astype(float)

toas_test_pta_2 = test_pta_2[psridx].toas().astype(float)*u.d.to('s')
res_test_pta_2 = test_pta_2[psridx].residuals().astype(float)

toas_test_pta_3 = test_pta_3[psridx].toas().astype(float)*u.d.to('s')
res_test_pta_3 = test_pta_3[psridx].residuals().astype(float)

ls_f_test_pta_1, ls_P_test_pta_1 = LombScargle(toas_test_pta_1,\
                                               res_test_pta_1,\
                                               normalization='psd').autopower()
ls_f_test_pta_2, ls_P_test_pta_2 = LombScargle(toas_test_pta_2,\
                                               res_test_pta_2,\
                                               normalization='psd').autopower()
ls_f_test_pta_3, ls_P_test_pta_3 = LombScargle(toas_test_pta_3,\
                                               res_test_pta_3,\
                                               normalization='psd').autopower()

# %% [markdown]
# ### FFT of residuals injected with the first way

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
ax1.loglog(ls_f_test_pta_1, ls_P_test_pta_1,'.')
ax1.set_title('libstempo inject')
ax1.set_ylabel('Power',fontsize=14)
ax1.set_xlabel(r'$f$',fontsize=14)

ax2.loglog(ls_f_test_pta_2, ls_P_test_pta_2,'.')
ax2.set_title('linspace inject')
ax2.set_xlabel(r'$f$',fontsize=14)

ax3.loglog(ls_f_test_pta_3, ls_P_test_pta_3,'.')
ax3.set_title('logspace inject')
ax3.set_xlabel(r'$f$',fontsize=14)
plt.show()

# %%
fig5,(ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
ax1.loglog(fft_test_pta_2,'x')
ax1.set_ylim(1e-9,1e-2)
ax1.set_title('linspace inject')
ax1.set_ylabel('Power',fontsize=14)
ax1.set_xlabel(r'$f$',fontsize=14)

ax2.loglog(fft_test_pta_3,'.')
ax2.set_ylim(1e-9,1e-2)
ax2.set_title('logspace inject')
ax2.set_xlabel(r'$f$',fontsize=14)
plt.show()
# Out:
# /Users/andrewkaiser/anaconda3/envs/enterprise/lib/python3.6/site-packages/matplotlib/ticker.py:2241: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   "Data has no positive values, and therefore cannot be "

# %% [markdown]
# ### FFT of residuals injected with the second way

# %%
toas_test_pta_4 = test_pta_4[psridx].toas().astype(float)*u.d.to('s')
res_test_pta_4 = test_pta_4[psridx].residuals().astype(float)

toas_test_pta_5 = test_pta_5[psridx].toas().astype(float)*u.d.to('s')
res_test_pta_5 = test_pta_5[psridx].residuals().astype(float)

ls_f_test_pta_4, ls_P_test_pta_4 = LombScargle(toas_test_pta_4,\
                                               res_test_pta_4,\
                                               normalization='psd').autopower()
ls_f_test_pta_5, ls_P_test_pta_5 = LombScargle(toas_test_pta_5,\
                                               res_test_pta_5,\
                                               normalization='psd').autopower()

# %%
fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(15,5))
ax1.loglog(ls_f_test_pta_1, ls_P_test_pta_1,'.')
ax1.set_title('libstempo inject')
ax1.set_ylabel('Power',fontsize=14)
ax1.set_xlabel(r'$f$',fontsize=14)

ax2.loglog(ls_f_test_pta_4, ls_P_test_pta_4,'.')
ax2.set_title('linspace inject')
ax2.set_xlabel(r'$f$',fontsize=14)

ax3.loglog(ls_f_test_pta_5, ls_P_test_pta_5,'.')
ax3.set_title('logspace inject')
ax3.set_xlabel(r'$f$',fontsize=14)
plt.show()

# %% [markdown]
# for ii,p in enumerate(t2psr):
#
#     ## make ideal
#     LT.make_ideal(p)
#
#     ## add efacs
#     LT.add_efac(p, efac = noise_dict[p.name]['efacs'][:,1],
#                 flagid = 'f', flags = noise_dict[p.name]['efacs'][:,0],
#                 seed = seed_efac + ii)
#
#     ## add equads
#     LT.add_equad(p, equad = noise_dict[p.name]['equads'][:,1],
#                  flagid = 'f', flags = noise_dict[p.name]['equads'][:,0],
#                  seed = seed_equad + ii)
#
#     ## add jitter
#     try: #Only NANOGrav Pulsars have ECORR
#         LT.add_jitter(p, ecorr = noise_dict[p.name]['ecorrs'][:,1],
#                       flagid='f', flags = noise_dict[p.name]['ecorrs'][:,0],
#                       coarsegrain = 1.0/86400.0, seed=seed_jitter + ii)
#     except KeyError:
#         pass
#
#     ## add red noise
#     LT.add_rednoise(p, noise_dict[p.name]['RN_Amp'], noise_dict[p.name]['RN_gamma'],
#                     components = 30, seed = seed_red + ii)
#
#     print(ii, p.name)

# %% [markdown]
# #Create GWB
# #Takes a list of libstempo pulsar objects as input.
# LT.createGWB(t2psr, Amp=1.3e-15, gam=13./3., seed=seed_gwb_1)
# LT.createGWB(t2psr, Amp=1.0e-15, gam=7./3., seed=seed_gwb_2)

# %% [markdown]
# #Load into enterprise
# psrs = []
# for p in t2psr:
#     psrs.append(Pulsar(p))

# %% [markdown]
# #Save sim pulsars to a pickle file
# with open(psr_pickle_file,'wb') as psrfile:
#     pickle.dump(psrs,psrfile)
#     psrfile.close()
