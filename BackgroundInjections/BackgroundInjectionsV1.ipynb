# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
import sys,os,glob,json
from collections import OrderedDict

import libstempo as T2
import libstempo.toasim as LT
import libstempo.plot as LP

import enterprise
from enterprise.pulsar import Pulsar
from enterprise.signals import parameter
from enterprise.signals import white_signals
from enterprise.signals import utils
from enterprise.signals import gp_signals
from enterprise.signals import signal_base
from enterprise.signals import selections
from enterprise.signals.selections import Selection

from enterprise_extensions import models,model_utils

import corner
from PTMCMCSampler.PTMCMCSampler import PTSampler as ptmcmc

# %matplotlib inline

# %%
def get_noise_from_pal2(noisefile):
    psrname = noisefile.split('/')[-1].split('_noise.txt')[0]
    fin = open(noisefile, 'r')
    lines = fin.readlines()
    params = {}
    for line in lines:
        ln = line.split()
        if 'efac' in line:
            par = 'efac'
            flag = ln[0].split('efac-')[-1]
        elif 'equad' in line:
            par = 'log10_equad'
            flag = ln[0].split('equad-')[-1]
        elif 'jitter_q' in line:
            par = 'log10_ecorr'
            flag = ln[0].split('jitter_q-')[-1]
        elif 'RN-Amplitude' in line:
            par = 'red_noise_log10_A'
            flag = ''
        elif 'RN-spectral-index' in line:
            par = 'red_noise_gamma'
            flag = ''
        else:
            break
        if flag:
            name = [psrname, flag, par]
        else:
            name = [psrname, par]
        pname = '_'.join(name)
        params.update({pname: float(ln[1])})
    return params

# %%
#Where the enterprise 11yr datafiles are
topdir = os.getcwd()

runname = '/simGWB_1'
#Where the everything should be saved to (chains, cornerplts, histograms, etc.)
outdir = topdir + '/SimRuns' + runname
if os.path.exists(outdir) == False:
    os.mkdir(outdir)

parpath = topdir + '/nano11/partim_new/'
timpath = topdir + '/nano11/partim_new/'
noisepath = topdir + '/nano11/noisefiles_new/'
psrlistpath = topdir + '/nano11/psrlist_Tg3yr.txt'

# %%
J1909_par = parpath + 'J1909-3744' + '_NANOGrav_11yv0.gls.par'
J1909_tim = timpath + 'J1909-3744' + '_NANOGrav_11yv0.tim'

# %%
J1909 = T2.tempopulsar(parfile = J1909_par, timfile = J1909_tim, maxobs=30000, ephem='DE436',clk=None)

# %%
t = np.arange(53000,56650,30.0) #observing dates for 10 years
t += np.random.randn(len(t)) #observe every 30+/-1 days

# %%
J0613_par = parpath +'J0613-0200' + '_NANOGrav_11yv0.gls.par'
fake_J0613=LT.fakepulsar(J0613_par,obstimes=t,toaerr=0.5)

# %%
encoding = "utf-8"
psrlist_bytes = np.loadtxt(psrlistpath,dtype='S42')
psrlist = []
for psr in psrlist_bytes:
    psrlist.append(psr.decode(encoding))

# %%
parfiles = sorted(glob.glob(parpath+'*.par'))
timfiles = sorted(glob.glob(timpath+'*.tim'))
noisefiles = sorted(glob.glob(noisepath+'*.txt'))

parfiles = [x for x in parfiles if x.split('/')[-1].split('.')[0].split('_')[0] in psrlist]
timfiles = [x for x in timfiles if x.split('/')[-1].split('.')[0].split('_')[0] in psrlist]
noisefiles = [x for x in noisefiles if x.split('/')[-1].split('_')[0] in psrlist]

print(len(parfiles),len(timfiles),len(noisefiles))
# Out:
# 34 34 34

# %%
#######################################
# PASSING THROUGH TEMPO2 VIA libstempo
#######################################

t2psr = []
for ii in range(len(parfiles)):
    
    t2psr.append( T2.tempopulsar(parfile = parfiles[ii], timfile = timfiles[ii],
                                 maxobs=30000, ephem='DE436') )
    
    if np.any(np.isfinite(t2psr[ii].residuals())==False)==True:
        t2psr[ii] = T2.tempopulsar(parfile = parfiles[ii], timfile = timfiles[ii])
                 

    print('\r{0} of {1}'.format(ii+1,len(parfiles)),flush=True,end='')
# Out:
# 34 of 34

# %%
noise_params = {}
for nf in noisefiles:
    noise_params.update(get_noise_from_pal2(nf))

# %%
#Now parse this large dictionary so that we can call noise parameters as noise_dict[pulsar name][noise type]
#Returns either floats or 2 column arrays of flags and values. 

noise_dict = {}
for p in psrlist:
    noise_dict[p]={}
    noise_dict[p]['equads'] = []
    noise_dict[p]['efacs'] = []
    noise_dict[p]['ecorrs'] = []
    for ky in list(noise_params.keys()):
        if p in ky:
            if 'equad' in ky:
                noise_dict[p]['equads'].append([ky.replace(p + '_' , ''), noise_params[ky]])
            if 'efac' in ky:
                noise_dict[p]['efacs'].append([ky.replace(p + '_' , ''), noise_params[ky]])
            if 'ecorr' in ky:
                noise_dict[p]['ecorrs'].append([ky.replace(p + '_' , ''), noise_params[ky]])
            if 'gamma' in ky:
                noise_dict[p]['RN_gamma'] = noise_params[ky]
            if 'log10_A' in ky:
                noise_dict[p]['RN_Amp'] = 10**noise_params[ky]
                
    noise_dict[p]['equads'] = np.array(noise_dict[p]['equads'])
    noise_dict[p]['efacs'] = np.array(noise_dict[p]['efacs'])
    noise_dict[p]['ecorrs'] = np.array(noise_dict[p]['ecorrs'])    
    
    if len(noise_dict[p]['ecorrs'])==0: #Easier to just delete these dictionary items if no ECORR values. 
        noise_dict[p].__delitem__('ecorrs')

# %%
#By using seeds we can  reproduce the dataset if need be. 
seed_efac = 1066
seed_equad = 1492
seed_jitter = 1776
seed_red = 1987
seed_gwb_1 = 1667
seed_gwb_2 = 1980

# %%
for ii,p in enumerate(t2psr):

    ## make ideal
    LT.make_ideal(p)

    ## add efacs
    LT.add_efac(p, efac = noise_dict[p.name]['efacs'][:,1], 
                flagid = 'f', flags = noise_dict[p.name]['efacs'][:,0], 
                seed = seed_efac + ii)

    ## add equads
    LT.add_equad(p, equad = noise_dict[p.name]['equads'][:,1], 
                 flagid = 'f', flags = noise_dict[p.name]['equads'][:,0], 
                 seed = seed_equad + ii)

    ## add jitter
    try: #Only NANOGrav Pulsars have ECORR
        LT.add_jitter(p, ecorr = noise_dict[p.name]['ecorrs'][:,1], 
                      flagid='f', flags = noise_dict[p.name]['ecorrs'][:,0], 
                      coarsegrain = 1.0/86400.0, seed=seed_jitter + ii)
    except KeyError:
        pass

    ## add red noise
    LT.add_rednoise(p, noise_dict[p.name]['RN_Amp'], noise_dict[p.name]['RN_gamma'], 
                    components = 30, seed = seed_red + ii)
    
    print(ii, p.name)
# Out:
# 0 B1855+09
# 1 B1937+21
# 2 B1953+29
# 3 J0023+0923
# 4 J0030+0451
# 5 J0340+4130
# 6 J0613-0200
# 7 J0645+5158
# 8 J1012+5307
# 9 J1024-0719
# 10 J1455-3330
# 11 J1600-3053
# 12 J1614-2230
# 13 J1640+2224
# 14 J1643-1224
# 15 J1713+0747
# 16 J1738+0333
# 17 J1741+1351
# 18 J1744-1134
# 19 J1747-4036
# 20 J1853+1303
# 21 J1903+0327
# 22 J1909-3744
# 23 J1910+1256
# 24 J1918-0642
# 25 J1923+2515
# 26 J1944+0907
# 27 J2010-1323
# 28 J2017+0603
# 29 J2043+1711
# 30 J2145-0750
# 31 J2214+3000
# 32 J2302+4442
# 33 J2317+1439

# %%
# Create GWB
# Takes a list of libstempo pulsar objects as input.
LT.createGWB(t2psr, Amp=1.5e-15, gam=13./3., seed=seed_gwb_1)
LT.createGWB(t2psr, Amp=9.0e-15, gam=10./3., seed=seed_gwb_2)

# %%
psrs = []
for p in t2psr:
    psrs.append(Pulsar(p))
# Out:
# WARNING: Could not find pulsar distance for PSR J0023+0923. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0340+4130. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0645+5158. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1614-2230. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1738+0333. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1741+1351. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1747-4036. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1853+1303. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1903+0327. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1923+2515. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1944+0907. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2010-1323. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2017+0603. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2043+1711. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2214+3000. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2302+4442. Setting value to 1 with 20% uncertainty.

# %%
# find the maximum time span to set GW frequency sampling
selection = Selection(selections.by_backend)

tmin = [p.toas.min() for p in psrs]
tmax = [p.toas.max() for p in psrs]
Tspan = np.max(tmax) - np.min(tmin)

##### parameters and priors #####

# white noise parameters
'''
efac = parameter.Uniform(0.5,4.0)
log10_equad = parameter.Uniform(-10,-5)
log10_ecorr = parameter.Uniform(-10,-5)
'''
efac = parameter.Constant()
log10_equad = parameter.Constant()
log10_ecorr = parameter.Constant()

# red noise parameters
red_noise_log10_A = parameter.Uniform(-18,-13)
red_noise_gamma = parameter.Uniform(0,7)

# GW parameters (initialize with names here to use parameters in common across pulsars)
log10_A_gw_1 = parameter.Uniform(-18,-13)('zlog10_A_gw_1')
gamma_gw_1 = parameter.Constant(13/3)('zgamma_gw_1')

# Second GW parameters
log10_A_gw_2 = parameter.Uniform(-18,-13)('zlog10_A_gw_2')
gamma_gw_2 = parameter.Constant(10/3)('zgamma_gw_2')

##### Set up signals #####

# timing model
tm = gp_signals.TimingModel()

# white noise
ef = white_signals.MeasurementNoise(efac=efac, selection=selection)
eq = white_signals.EquadNoise(log10_equad = log10_equad, selection=selection)
ec = white_signals.EcorrKernelNoise(log10_ecorr = log10_ecorr, selection=selection)

# red noise (powerlaw with 30 frequencies)
pl = utils.powerlaw(log10_A=red_noise_log10_A, gamma=red_noise_gamma)
rn = gp_signals.FourierBasisGP(spectrum=pl, components=30, Tspan=Tspan)

cpl_1 = utils.powerlaw(log10_A=log10_A_gw_1, gamma=gamma_gw_2)
cpl_2 = utils.powerlaw(log10_A=log10_A_gw_2, gamma=gamma_gw_2)

#Common red noise process with no correlations
#crn = gp_signals.FourierBasisGP(spectrum = cpl, components=30, Tspan=Tspan, name = 'gw')

# gwb with Hellings and Downs correlations
# Hellings and Downs ORF
orf = utils.hd_orf()
gwb_1 = gp_signals.FourierBasisCommonGP(cpl_1, orf, components=30, name='gw_1', Tspan=Tspan)
gwb_2 = gp_signals.FourierBasisCommonGP(cpl_2, orf, components=30, name='gw_2', Tspan=Tspan)

# full model is sum of components
model = ef + eq + ec + rn + tm + gwb_1 + gwb_2  #+ crn

# initialize PTA
pta = signal_base.PTA([model(psr) for psr in psrs])

# %%
with open(outdir + '/parameters.json', 'w') as fp:
    json.dump(pta.param_names, fp)

# %%
#Set Default PTA parameters to the ones in the noisefiles
pta.set_default_params(noise_params)
# Out:
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_ASP_efac to 1.16587
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_PUPPI_efac to 1.11896
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_ASP_efac to 1.08538
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_PUPPI_efac to 1.38104
# INFO: enterprise.signals.signal_base: Setting B1855+09_430
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GUPPI_log10_equad to -7.1468
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_ASP_log10_equad to -8.51229
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_PUPPI_log10_equad to -7.63137
# INFO: enterprise.signals.signal_base: Setting J1713+0747_L-wide_ASP_log10_ecorr to -6.94698
# INFO: enterprise.signals.signal_base: Setting J1713+0747_L-wide_PUPPI_log10_ecorr to -7.04506
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr1_2_GASP_log10_ecorr to -7.13048
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr1_2_GUPPI_log10_ecorr to -7.12592
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GASP_log10_ecorr to -8.37185
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GUPPI_log10_ecorr to -6.63113
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_ASP_log10_ecorr to -6.956
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_PUPPI_log10_ecorr to -7.01837
# INFO: enterprise.signals.signal_base: Setting J1738+0333_L-wide_ASP_efac to 1.14904
# INFO: enterprise.signals.signal_base: Setting J1738+0333_L-wide_PUPPI_efac to 1.129
# INFO: enterprise.signals.signal_base: Setting J1738+0333_S-wide_ASP_efac to 0.938248
# INFO: enterprise.signals.signal_base: Setting J1738+0333_S-wide_PUPPI_efac to 0.919547
# INFO: enterprise.signals.signal_base: Setting J1738+0333_L-wide_ASP_log10_equad to -8.10998
# INFO: enterprise.signals.signal_base: Setting J1738+0333_L-wide_PUPPI_log10_equad to -9.96604
# INFO: enterprise.signals.signal_base: Setting J1738+0333_S-wide_ASP_log10_equad to -7.53561
# INFO: enterprise.signals.signal_base: Setting J1738+0333_S-wide_PUPPI_log10_equad to -9.07389
# INFO: enterprise.signals.signal_base: Setting J1738+0333_L-wide_ASP_log10_ecorr to -6.40914
# INFO: enterprise.signals.signal_base: Setting J1738+0333_L-wide_PUPPI_log10_ecorr to -6.86208
# INFO: enterprise.signals.signal_base: Setting J1738+0333_S-wide_ASP_log10_ecorr to -7.14468
# INFO: enterprise.signals.signal_base: Setting J1738+0333_S-wide_PUPPI_log10_ecorr to -8.4514
# INFO: enterprise.signals.signal_base: Setting J1741+1351_430_ASP_efac to 0.943356
# INFO: enterprise.signals.signal_base: Setting J1741+1351_430_PUPPI_efac to 1.03811
# INFO: enterprise.signals.signal_base: Setting J1741+1351_L-wide_ASP_efac to 1.03779
# INFO: enterprise.signals.signal_base: Setting J1741+1351_L-wide_PUPPI_efac to 1.04885
# INFO: enterprise.signals.signal_base: Setting J1741+1351_S-wide_ASP_efac to 0.669143
# INFO: enterprise.signals.signal_base: Setting J1741+1351_430_ASP_log10_equad to -6.43607
# INFO: enterprise.signals.signal_base: Setting J1741+1351_430_PUPPI_log10_equad to -6.57596
# INFO: enterprise.signals.signal_base: Setting J1741+1351_L-wide_ASP_log10_equad to -7.2559
# INFO: enterprise.signals.signal_base: Setting J1741+1351_L-wide_PUPPI_log10_equad to -7.17192
# INFO: enterprise.signals.signal_base: Setting J1741+1351_S-wide_ASP_log10_equad to -9.94364
# INFO: enterprise.signals.signal_base: Setting J1741+1351_430_ASP_log10_ecorr to -7.44991
# INFO: enterprise.signals.signal_base: Setting J1741+1351_430_PUPPI_log10_ecorr to -8.21022
# INFO: enterprise.signals.signal_base: Setting J1741+1351_L-wide_ASP_log10_ecorr to -7.65893
# INFO: enterprise.signals.signal_base: Setting J1741+1351_L-wide_PUPPI_log10_ecorr to -7.05294
# INFO: enterprise.signals.signal_base: Setting J1741+1351_S-wide_ASP_log10_ecorr to -7.49525
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr1_2_GASP_efac to 0.99538
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr1_2_GUPPI_efac to 1.07954
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr_800_GASP_efac to 1.16696
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr_800_GUPPI_efac to 1.07204
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr1_2_GASP_log10_equad to -6.38482
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr1_2_GUPPI_log10_equad to -6.68218
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr_800_GASP_log10_equad to -6.46771
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr_800_GUPPI_log10_equad to -6.60145
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr1_2_GASP_log10_ecorr to -6.18673
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr1_2_GUPPI_log10_ecorr to -6.37018
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr_800_GASP_log10_ecorr to -6.61101
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr_800_GUPPI_log10_ecorr to -6.41914
# INFO: enterprise.signals.signal_base: Setting J1747-4036_Rcvr1_2_GUPPI_efac to 1.12904
# INFO: enterprise.signals.signal_base: Setting J1747-4036_Rcvr_800_GUPPI_efac to 1.13382
# INFO: enterprise.signals.signal_base: Setting J1747-4036_Rcvr1_2_GUPPI_log10_equad to -7.40759
# INFO: enterprise.signals.signal_base: Setting J1747-4036_Rcvr_800_GUPPI_log10_equad to -5.94769
# INFO: enterprise.signals.signal_base: Setting J1747-4036_Rcvr1_2_GUPPI_log10_ecorr to -5.83548
# INFO: enterprise.signals.signal_base: Setting J1747-4036_Rcvr_800_GUPPI_log10_ecorr to -5.34385
# INFO: enterprise.signals.signal_base: Setting J1853+1303_430_ASP_efac to 1.06278
# INFO: enterprise.signals.signal_base: Setting J1853+1303_430_PUPPI_efac to 1.01473
# INFO: enterprise.signals.signal_base: Setting J1853+1303_L-wide_ASP_efac to 1.04814
# INFO: enterprise.signals.signal_base: Setting J1853+1303_L-wide_PUPPI_efac to 1.16007
# INFO: enterprise.signals.signal_base: Setting J1853+1303_430_ASP_log10_equad to -6.1864
# INFO: enterprise.signals.signal_base: Setting J1853+1303_430_PUPPI_log10_equad to -6.47845
# INFO: enterprise.signals.signal_base: Setting J1853+1303_L-wide_ASP_log10_equad to -7.03999
# INFO: enterprise.signals.signal_base: Setting J1853+1303_L-wide_PUPPI_log10_equad to -8.03066
# INFO: enterprise.signals.signal_base: Setting J1853+1303_430_ASP_log10_ecorr to -6.78935
# INFO: enterprise.signals.signal_base: Setting J1853+1303_430_PUPPI_log10_ecorr to -6.05781
# INFO: enterprise.signals.signal_base: Setting J1853+1303_L-wide_ASP_log10_ecorr to -5.95433
# INFO: enterprise.signals.signal_base: Setting J1853+1303_L-wide_PUPPI_log10_ecorr to -6.73663
# INFO: enterprise.signals.signal_base: Setting J1903+0327_L-wide_ASP_efac to 1.17318
# INFO: enterprise.signals.signal_base: Setting J1903+0327_L-wide_PUPPI_efac to 1.15515
# INFO: enterprise.signals.signal_base: Setting J1903+0327_S-wide_ASP_efac to 0.886052
# INFO: enterprise.signals.signal_base: Setting J1903+0327_S-wide_PUPPI_efac to 1.09208
# INFO: enterprise.signals.signal_base: Setting J1903+0327_L-wide_ASP_log10_equad to -7.35457
# INFO: enterprise.signals.signal_base: Setting J1903+0327_L-wide_PUPPI_log10_equad to -8.99143
# INFO: enterprise.signals.signal_base: Setting J1903+0327_S-wide_ASP_log10_equad to -5.79449
# INFO: enterprise.signals.signal_base: Setting J1903+0327_S-wide_PUPPI_log10_equad to -9.96083
# INFO: enterprise.signals.signal_base: Setting J1903+0327_L-wide_ASP_log10_ecorr to -7.40195
# INFO: enterprise.signals.signal_base: Setting J1903+0327_L-wide_PUPPI_log10_ecorr to -5.62293
# INFO: enterprise.signals.signal_base: Setting J1903+0327_S-wide_ASP_log10_ecorr to -8.19334
# INFO: enterprise.signals.signal_base: Setting J1903+0327_S-wide_PUPPI_log10_ecorr to -6.21037
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr1_2_GASP_efac to 0.972335
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr1_2_GUPPI_efac to 1.05106
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr_800_GASP_efac to 0.988698
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr_800_GUPPI_efac to 1.04206
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr1_2_GASP_log10_equad to -7.42188
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr1_2_GUPPI_log10_equad to -8.0764
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr_800_GASP_log10_equad to -6.62323
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr_800_GUPPI_log10_equad to -7.33552
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr1_2_GASP_log10_ecorr to -8.42225
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr1_2_GUPPI_log10_ecorr to -7.12549
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr_800_GASP_log10_ecorr to -8.15612
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr_800_GUPPI_log10_ecorr to -7.22182
# INFO: enterprise.signals.signal_base: Setting J1910+1256_L-wide_ASP_efac to 1.06735
# INFO: enterprise.signals.signal_base: Setting J1910+1256_L-wide_PUPPI_efac to 1.14184
# INFO: enterprise.signals.signal_base: Setting J1910+1256_S-wide_ASP_efac to 0.958043
# INFO: enterprise.signals.signal_base: Setting J1910+1256_S-wide_PUPPI_efac to 1.15893
# INFO: enterprise.signals.signal_base: Setting J1910+1256_L-wide_ASP_log10_equad to -9.00384
# INFO: enterprise.signals.signal_base: Setting J1910+1256_L-wide_PUPPI_log10_equad to -7.7184
# INFO: enterprise.signals.signal_base: Setting J1910+1256_S-wide_ASP_log10_equad to -6.13141
# INFO: enterprise.signals.signal_base: Setting J1910+1256_S-wide_PUPPI_log10_equad to -6.0419
# INFO: enterprise.signals.signal_base: Setting J1910+1256_L-wide_ASP_log10_ecorr to -8.15332
# INFO: enterprise.signals.signal_base: Setting J1910+1256_L-wide_PUPPI_log10_ecorr to -6.15794
# INFO: enterprise.signals.signal_base: Setting J1910+1256_S-wide_ASP_log10_ecorr to -8.09846
# INFO: enterprise.signals.signal_base: Setting J1910+1256_S-wide_PUPPI_log10_ecorr to -5.80553
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr1_2_GASP_efac to 1.03669
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr1_2_GUPPI_efac to 1.07037
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr_800_GASP_efac to 1.05582
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr_800_GUPPI_efac to 1.03233
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr1_2_GASP_log10_equad to -9.9641
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr1_2_GUPPI_log10_equad to -6.67237
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr_800_GASP_log10_equad to -6.52326
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr_800_GUPPI_log10_equad to -6.50585
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr1_2_GASP_log10_ecorr to -6.48484
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr1_2_GUPPI_log10_ecorr to -7.12901
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr_800_GASP_log10_ecorr to -7.68959
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr_800_GUPPI_log10_ecorr to -6.50566
# INFO: enterprise.signals.signal_base: Setting J1923+2515_430_ASP_efac to 1.17799
# INFO: enterprise.signals.signal_base: Setting J1923+2515_430_PUPPI_efac to 1.0694
# INFO: enterprise.signals.signal_base: Setting J1923+2515_L-wide_ASP_efac to 0.889525
# INFO: enterprise.signals.signal_base: Setting J1923+2515_L-wide_PUPPI_efac to 1.2206
# INFO: enterprise.signals.signal_base: Setting J1923+2515_430_ASP_log10_equad to -9.66569
# INFO: enterprise.signals.signal_base: Setting J1923+2515_430_PUPPI_log10_equad to -8.02799
# INFO: enterprise.signals.signal_base: Setting J1923+2515_L-wide_ASP_log10_equad to -7.37365
# INFO: enterprise.signals.signal_base: Setting J1923+2515_L-wide_PUPPI_log10_equad to -9.67228
# INFO: enterprise.signals.signal_base: Setting J1923+2515_430_ASP_log10_ecorr to -4.87328
# INFO: enterprise.signals.signal_base: Setting J1923+2515_430_PUPPI_log10_ecorr to -7.33154
# INFO: enterprise.signals.signal_base: Setting J1923+2515_L-wide_ASP_log10_ecorr to -5.93883
# INFO: enterprise.signals.signal_base: Setting J1923+2515_L-wide_PUPPI_log10_ecorr to -7.76522
# INFO: enterprise.signals.signal_base: Setting J1944+0907_430_ASP_efac to 1.10927
# INFO: enterprise.signals.signal_base: Setting J1944+0907_430_PUPPI_efac to 1.12406
# INFO: enterprise.signals.signal_base: Setting J1944+0907_L-wide_ASP_efac to 1.57944
# INFO: enterprise.signals.signal_base: Setting J1944+0907_L-wide_PUPPI_efac to 1.24916
# INFO: enterprise.signals.signal_base: Setting J1944+0907_430_ASP_log10_equad to -6.42868
# INFO: enterprise.signals.signal_base: Setting J1944+0907_430_PUPPI_log10_equad to -9.44541
# INFO: enterprise.signals.signal_base: Setting J1944+0907_L-wide_ASP_log10_equad to -6.9667
# INFO: enterprise.signals.signal_base: Setting J1944+0907_L-wide_PUPPI_log10_equad to -8.94465
# INFO: enterprise.signals.signal_base: Setting J1944+0907_430_ASP_log10_ecorr to -5.12129
# INFO: enterprise.signals.signal_base: Setting J1944+0907_430_PUPPI_log10_ecorr to -6.7808
# INFO: enterprise.signals.signal_base: Setting J1944+0907_L-wide_ASP_log10_ecorr to -6.22896
# INFO: enterprise.signals.signal_base: Setting J1944+0907_L-wide_PUPPI_log10_ecorr to -6.53852
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr1_2_GASP_efac to 1.02807
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr1_2_GUPPI_efac to 1.18061
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr_800_GASP_efac to 1.06913
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr_800_GUPPI_efac to 1.02707
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr1_2_GASP_log10_equad to -5.9829
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr1_2_GUPPI_log10_equad to -8.90443
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr_800_GASP_log10_equad to -6.71382
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr_800_GUPPI_log10_equad to -9.2115
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr1_2_GASP_log10_ecorr to -6.17032
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr1_2_GUPPI_log10_ecorr to -6.92687
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr_800_GASP_log10_ecorr to -8.46441
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr_800_GUPPI_log10_ecorr to -7.68919
# INFO: enterprise.signals.signal_base: Setting J2017+0603_430_PUPPI_efac to 1.02547
# INFO: enterprise.signals.signal_base: Setting J2017+0603_L-wide_PUPPI_efac to 1.17397
# INFO: enterprise.signals.signal_base: Setting J2017+0603_S-wide_PUPPI_efac to 1.12009
# INFO: enterprise.signals.signal_base: Setting J2017+0603_430_PUPPI_log10_equad to -9.62256
# INFO: enterprise.signals.signal_base: Setting J2017+0603_L-wide_PUPPI_log10_equad to -9.81872
# INFO: enterprise.signals.signal_base: Setting J2017+0603_S-wide_PUPPI_log10_equad to -8.42813
# INFO: enterprise.signals.signal_base: Setting J2017+0603_430_PUPPI_log10_ecorr to -7.00314
# INFO: enterprise.signals.signal_base: Setting J2017+0603_L-wide_PUPPI_log10_ecorr to -8.47894
# INFO: enterprise.signals.signal_base: Setting J2017+0603_S-wide_PUPPI_log10_ecorr to -7.88655
# INFO: enterprise.signals.signal_base: Setting J2043+1711_430_ASP_efac to 1.31143
# INFO: enterprise.signals.signal_base: Setting J2043+1711_430_PUPPI_efac to 1.05645
# INFO: enterprise.signals.signal_base: Setting J2043+1711_L-wide_ASP_efac to 1.13338
# INFO: enterprise.signals.signal_base: Setting J2043+1711_L-wide_PUPPI_efac to 1.05179
# INFO: enterprise.signals.signal_base: Setting J2043+1711_430_ASP_log10_equad to -9.33212
# INFO: enterprise.signals.signal_base: Setting J2043+1711_430_PUPPI_log10_equad to -6.73935
# INFO: enterprise.signals.signal_base: Setting J2043+1711_L-wide_ASP_log10_equad to -8.27855
# INFO: enterprise.signals.signal_base: Setting J2043+1711_L-wide_PUPPI_log10_equad to -9.44568
# INFO: enterprise.signals.signal_base: Setting J2043+1711_430_ASP_log10_ecorr to -7.89188
# INFO: enterprise.signals.signal_base: Setting J2043+1711_430_PUPPI_log10_ecorr to -6.24811
# INFO: enterprise.signals.signal_base: Setting J2043+1711_L-wide_ASP_log10_ecorr to -7.30795
# INFO: enterprise.signals.signal_base: Setting J2043+1711_L-wide_PUPPI_log10_ecorr to -7.60065
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr1_2_GASP_efac to 0.974005
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr1_2_GUPPI_efac to 1.09808
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr_800_GASP_efac to 1.40923
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr_800_GUPPI_efac to 1.13029
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr1_2_GASP_log10_equad to -5.69239
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr1_2_GUPPI_log10_equad to -6.3085
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr_800_GASP_log10_equad to -6.5184
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr_800_GUPPI_log10_equad to -6.28322
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr1_2_GASP_log10_ecorr to -6.10416
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr1_2_GUPPI_log10_ecorr to -6.3658
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr_800_GASP_log10_ecorr to -6.21865
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr_800_GUPPI_log10_ecorr to -6.63312
# INFO: enterprise.signals.signal_base: Setting J2214+3000_L-wide_ASP_efac to 0.691955
# INFO: enterprise.signals.signal_base: Setting J2214+3000_L-wide_PUPPI_efac to 1.21625
# INFO: enterprise.signals.signal_base: Setting J2214+3000_S-wide_ASP_efac to 0.945361
# INFO: enterprise.signals.signal_base: Setting J2214+3000_S-wide_PUPPI_efac to 1.12808
# INFO: enterprise.signals.signal_base: Setting J2214+3000_L-wide_ASP_log10_equad to -9.59856
# INFO: enterprise.signals.signal_base: Setting J2214+3000_L-wide_PUPPI_log10_equad to -7.22034
# INFO: enterprise.signals.signal_base: Setting J2214+3000_S-wide_ASP_log10_equad to -5.11084
# INFO: enterprise.signals.signal_base: Setting J2214+3000_S-wide_PUPPI_log10_equad to -6.23008
# INFO: enterprise.signals.signal_base: Setting J2214+3000_L-wide_ASP_log10_ecorr to -6.40982
# INFO: enterprise.signals.signal_base: Setting J2214+3000_L-wide_PUPPI_log10_ecorr to -6.93999
# INFO: enterprise.signals.signal_base: Setting J2214+3000_S-wide_ASP_log10_ecorr to -6.47446
# INFO: enterprise.signals.signal_base: Setting J2214+3000_S-wide_PUPPI_log10_ecorr to -5.69464
# INFO: enterprise.signals.signal_base: Setting J2302+4442_Rcvr1_2_GUPPI_efac to 1.16926
# INFO: enterprise.signals.signal_base: Setting J2302+4442_Rcvr_800_GUPPI_efac to 1.0388
# INFO: enterprise.signals.signal_base: Setting J2302+4442_Rcvr1_2_GUPPI_log10_equad to -8.37325
# INFO: enterprise.signals.signal_base: Setting J2302+4442_Rcvr_800_GUPPI_log10_equad to -9.36685
# INFO: enterprise.signals.signal_base: Setting J2302+4442_Rcvr1_2_GUPPI_log10_ecorr to -6.16308
# INFO: enterprise.signals.signal_base: Setting J2302+4442_Rcvr_800_GUPPI_log10_ecorr to -6.10074
# INFO: enterprise.signals.signal_base: Setting J2317+1439_327_ASP_efac to 1.07331
# INFO: enterprise.signals.signal_base: Setting J2317+1439_327_PUPPI_efac to 1.21963
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_ASP_efac to 1.2495
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_PUPPI_efac to 1.02725
# INFO: enterprise.signals.signal_base: Setting J2317+1439_L-wide_PUPPI_efac to 1.21484
# INFO: enterprise.signals.signal_base: Setting J2317+1439_327_ASP_log10_equad to -6.41859
# INFO: enterprise.signals.signal_base: Setting J2317+1439_327_PUPPI_log10_equad to -6.43463
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_ASP_log10_equad to -6.69096
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_PUPPI_log10_equad to -6.51926
# INFO: enterprise.signals.signal_base: Setting J2317+1439_L-wide_PUPPI_log10_equad to -7.26062
# INFO: enterprise.signals.signal_base: Setting J2317+1439_327_ASP_log10_ecorr to -6.24766
# INFO: enterprise.signals.signal_base: Setting J2317+1439_327_PUPPI_log10_ecorr to -7.88518
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_ASP_log10_ecorr to -6.23565
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_PUPPI_log10_ecorr to -6.26958
# INFO: enterprise.signals.signal_base: Setting J2317+1439_L-wide_PUPPI_log10_ecorr to -7.15128

# %%
#Pick random initial sampling
xs = {par.name: par.sample() for par in pta.params}

# dimension of parameter space
ndim = len(xs)

# initial jump covariance matrix
cov = np.diag(np.ones(ndim) * 0.01**2)

groups = model_utils.get_parameter_groups(pta)
groups.append([ndim-2,ndim-1])

# %%
# intialize sampler
sampler = ptmcmc(ndim, pta.get_lnlikelihood, pta.get_lnprior, cov, groups=groups, outDir = outdir,resume=True)

# sampler for N steps
N = int(1e5)
x0 = np.hstack(p.sample() for p in pta.params)
sampler.sample(x0, N, SCAMweight=30, AMweight=15, DEweight=50)
# Out:
# Finished 1.00 percent in 842.297933 s Acceptance rate = 0.856
# /Users/andrewkaiser/anaconda3/envs/enterprise/lib/python3.6/site-packages/enterprise/signals/parameter.py:66: RuntimeWarning: divide by zero encountered in log
#   logpdf = np.log(self.prior(value, **kwargs))
# Finished 8.00 percent in 7551.538500 s Acceptance rate = 0.682759
