# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
from __future__ import division

import numpy as np
import glob
import matplotlib.pyplot as plt
import scipy.sparse as sps
import scipy.linalg as sl
from scipy.stats import chi2
import time

import enterprise
from enterprise.pulsar import Pulsar
from enterprise.signals import parameter
from enterprise.signals import white_signals
from enterprise.signals import utils
from enterprise.signals import gp_signals
from enterprise.signals import signal_base
from enterprise.signals import selections
from enterprise.signals.selections import Selection

import corner
from PTMCMCSampler.PTMCMCSampler import PTSampler as ptmcmc
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-63683c2398bb> in <module>()
#       9 import time
#      10
# ---> 11 import enterprise
#      12 from enterprise.pulsar import Pulsar
#      13 from enterprise.signals import parameter
#
# ModuleNotFoundError: No module named 'enterprise'

# %%
def get_noise_from_pal2(noisefile):
    psrname = noisefile.split('/')[-1].split('_noise.txt')[0]
    fin = open(noisefile, 'r')
    lines = fin.readlines()
    params = {}
    for line in lines:
        ln = line.split()
        if 'efac' in line:
            par = 'efac'
            flag = ln[0].split('efac-')[-1]
        elif 'equad' in line:
            par = 'log10_equad'
            flag = ln[0].split('equad-')[-1]
        elif 'jitter_q' in line:
            par = 'log10_ecorr'
            flag = ln[0].split('jitter_q-')[-1]
        elif 'RN-Amplitude' in line:
            par = 'red_noise_log10_A'
            flag = ''
        elif 'RN-spectral-index' in line:
            par = 'red_noise_gamma'
            flag = ''
        else:
            break
        if flag:
            name = [psrname, flag, par]
        else:
            name = [psrname, par]
        pname = '_'.join(name)
        params.update({pname: float(ln[1])})
    return params

# %%
datadir = enterprise.__path__[0] + '/datafiles/ng9/'

parfiles = sorted(glob.glob(datadir + '/*.par'))
timfiles = sorted(glob.glob(datadir + '/*.tim'))
noisefiles = sorted(glob.glob(datadir + '/*noise.txt'))

# %%
#Trial with a few pulsars
parfile_J0030 = datadir + 'J0030+0451_NANOGrav_9yv1.gls.par'
parfile_B1937 = datadir + 'B1937+21_NANOGrav_9yv1.gls.par'

timfile_J0030 = datadir + 'J0030+0451_NANOGrav_9yv1.tim'
timfile_B1937 = datadir + 'B1937+21_NANOGrav_9yv1.tim'

noisefile_J0030 = datadir + 'J0030+0451_noise.txt'
noisefile_B1937 = datadir + 'B1937+21_noise.txt'

psr_J0030 = Pulsar(parfile_J0030,timfile_J0030)
psr_B1937 = Pulsar(parfile_B1937,timfile_B1937)

psrs_test = [psr_J0030,psr_B1937]

#Get parameter dict from noisefiles
params_test = {}
params_test.update(get_noise_from_pal2(noisefile_J0030))
params_test.update(get_noise_from_pal2(noisefile_B1937))

# %%
#All of the Pulsars! Except J0218+4232 because it is naughty and doesn't have a noise file.
psrs_full = []

for p, t in zip(parfiles, timfiles):
    psr = Pulsar(p, t)
    if psr.name != 'J0218+4232':
        psrs_full.append(psr)
# Out:
# WARNING: Could not find pulsar distance for PSR J0023+0923. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0218+4232. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0340+4130. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0645+5158. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J0931-1902. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1614-2230. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1738+0333. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1741+1351. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1747-4036. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1832-0836. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1853+1303. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1903+0327. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1923+2515. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1944+0907. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J1949+3106. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2010-1323. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2017+0603. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2043+1711. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2214+3000. Setting value to 1 with 20% uncertainty.
# WARNING: Could not find pulsar distance for PSR J2302+4442. Setting value to 1 with 20% uncertainty.

# %%
#Get parameter dict from noisefiles
params_full = {}
for nfile in noisefiles:
    params_full.update(get_noise_from_pal2(nfile))

# %%
def GetTspan(psrs):
    tmin = [p.toas.min() for p in psrs]
    tmax = [p.toas.max() for p in psrs]
    Tspan = np.max(tmax) - np.min(tmin)
    return Tspan

# %%
##### parameters and priors #####
selection = Selection(selections.by_backend)

Tspan_full = GetTspan(psrs_full)
Tspan_test = GetTspan(psrs_test)

# white noise parameters
efac = parameter.Constant()
log10_equad = parameter.Constant()
ecorr = parameter.Constant()

# red noise parameters
log10_A = parameter.Constant()
gamma = parameter.Constant()

'''
# GW parameters (initialize with names here to use parameters in common across pulsars)
log10_A_gw = parameter.LinearExp(-18,-12)('log10_A_gw')
gamma_gw = parameter.Constant(4.33)('gamma_gw')
'''

# red noise (powerlaw with 30 frequencies)
pl = utils.powerlaw(log10_A=log10_A, gamma=gamma)
rn_f = gp_signals.FourierBasisGP(spectrum=pl, Tspan=Tspan_full)
rn_t = gp_signals.FourierBasisGP(spectrum=pl, Tspan=Tspan_test)

'''
# gwb (no spatial correlations)
cpl = utils.powerlaw(log10_A=log10_A_gw, gamma=gamma_gw)
gw = gp_signals.FourierBasisGP(spectrum=cpl, components=30, Tspan=Tspan)
'''

# timing model
tm = gp_signals.TimingModel()

##### Set up signals #####

# white noise
ef = white_signals.MeasurementNoise(efac=efac, selection=selection)
eq = white_signals.EquadNoise(log10_equad=log10_equad, selection=selection)
ec = white_signals.EcorrKernelNoise(log10_ecorr=ecorr, selection=selection)

# full model is sum of components
model_full = tm + ef + eq + ec + rn_f
model_test = tm + ef + eq + ec + rn_t

# intialize PTA
pta_test = signal_base.PTA([model_full(psr) for psr in psrs_test])
pta_full = signal_base.PTA([model_test(psr) for psr in psrs_full])

# %%
#Set Default PTA parameters to the ones in the noisefiles
pta_test.set_default_params(params_test)
pta_full.set_default_params(params_full)
# Out:
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_ASP_efac to 1.13871
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_PUPPI_efac to 0.917359
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_ASP_efac to 1.12336
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_PUPPI_efac to 1.14101
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_ASP_log10_equad to -8.27762
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_PUPPI_log10_equad to -5.94568
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_ASP_log10_equad to -8.17663
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_PUPPI_log10_equad to -6.67303
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_ASP_log10_ecorr to -7.6001
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_PUPPI_log10_ecorr to -7.11084
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_ASP_log10_ecorr to -7.59912
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_PUPPI_log10_ecorr to -7.64239
# INFO: enterprise.signals.signal_base: Setting J0030+0451_red_noise_log10_A to -14.412
# INFO: enterprise.signals.signal_base: Setting J0030+0451_red_noise_gamma to 5.05806
# INFO: enterprise.signals.signal_base: Setting B1937+21_L-wide_ASP_efac to 2.06
# INFO: enterprise.signals.signal_base: Setting B1937+21_L-wide_PUPPI_efac to 2.396
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr1_2_GASP_efac to 1.217
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr1_2_GUPPI_efac to 1.618
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr_800_GASP_efac to 2.076
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr_800_GUPPI_efac to 4.799
# INFO: enterprise.signals.signal_base: Setting B1937+21_S-wide_ASP_efac to 1.289
# INFO: enterprise.signals.signal_base: Setting B1937+21_S-wide_PUPPI_efac to 3.941
# INFO: enterprise.signals.signal_base: Setting B1937+21_L-wide_ASP_log10_equad to -7.11351
# INFO: enterprise.signals.signal_base: Setting B1937+21_L-wide_PUPPI_log10_equad to -7.5376
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr1_2_GASP_log10_equad to -7.19382
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr1_2_GUPPI_log10_equad to -7.38722
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr_800_GASP_log10_equad to -6.98716
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr_800_GUPPI_log10_equad to -7.35655
# INFO: enterprise.signals.signal_base: Setting B1937+21_S-wide_ASP_log10_equad to -6.62525
# INFO: enterprise.signals.signal_base: Setting B1937+21_S-wide_PUPPI_log10_equad to -7.56864
# INFO: enterprise.signals.signal_base: Setting B1937+21_L-wide_ASP_log10_ecorr to -6.64016
# INFO: enterprise.signals.signal_base: Setting B1937+21_L-wide_PUPPI_log10_ecorr to -6.82974
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr1_2_GASP_log10_ecorr to -7.03621
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr1_2_GUPPI_log10_ecorr to -6.61261
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr_800_GASP_log10_ecorr to -8.22185
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr_800_GUPPI_log10_ecorr to -6.44612
# INFO: enterprise.signals.signal_base: Setting B1937+21_S-wide_ASP_log10_ecorr to -6.56067
# INFO: enterprise.signals.signal_base: Setting B1937+21_S-wide_PUPPI_log10_ecorr to -6.79048
# INFO: enterprise.signals.signal_base: Setting B1937+21_red_noise_log10_A to -13.1687
# INFO: enterprise.signals.signal_base: Setting B1937+21_red_noise_gamma to 2.41503
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_ASP_efac to 1.13965
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_PUPPI_efac to 1.12121
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_ASP_efac to 1.14383
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_PUPPI_efac to 1.51117
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_ASP_log10_equad to -8.09925
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_PUPPI_log10_equad to -7.96027
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_ASP_log10_equad to -6.31998
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_PUPPI_log10_equad to -6.42638
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_ASP_log10_ecorr to -7.38511
# INFO: enterprise.signals.signal_base: Setting B1855+09_430_PUPPI_log10_ecorr to -7.28084
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_ASP_log10_ecorr to -6.10018
# INFO: enterprise.signals.signal_base: Setting B1855+09_L-wide_PUPPI_log10_ecorr to -6.48309
# INFO: enterprise.signals.signal_base: Setting B1855+09_red_noise_log10_A to -13.8485
# INFO: enterprise.signals.signal_base: Setting B1855+09_red_noise_gamma to 3.88472
# INFO: enterprise.signals.signal_base: Setting B1937+21_L-wide_ASP_efac to 2.06
# INFO: enterprise.signals.signal_base: Setting B1937+21_L-wide_PUPPI_efac to 2.396
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr1_2_GASP_efac to 1.217
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr1_2_GUPPI_efac to 1.618
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr_800_GASP_efac to 2.076
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr_800_GUPPI_efac to 4.799
# INFO: enterprise.signals.signal_base: Setting B1937+21_S-wide_ASP_efac to 1.289
# INFO: enterprise.signals.signal_base: Setting B1937+21_S-wide_PUPPI_efac to 3.941
# INFO: enterprise.signals.signal_base: Setting B1937+21_L-wide_ASP_log10_equad to -7.11351
# INFO: enterprise.signals.signal_base: Setting B1937+21_L-wide_PUPPI_log10_equad to -7.5376
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr1_2_GASP_log10_equad to -7.19382
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr1_2_GUPPI_log10_equad to -7.38722
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr_800_GASP_log10_equad to -6.98716
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr_800_GUPPI_log10_equad to -7.35655
# INFO: enterprise.signals.signal_base: Setting B1937+21_S-wide_ASP_log10_equad to -6.62525
# INFO: enterprise.signals.signal_base: Setting B1937+21_S-wide_PUPPI_log10_equad to -7.56864
# INFO: enterprise.signals.signal_base: Setting B1937+21_L-wide_ASP_log10_ecorr to -6.64016
# INFO: enterprise.signals.signal_base: Setting B1937+21_L-wide_PUPPI_log10_ecorr to -6.82974
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr1_2_GASP_log10_ecorr to -7.03621
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr1_2_GUPPI_log10_ecorr to -6.61261
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr_800_GASP_log10_ecorr to -8.22185
# INFO: enterprise.signals.signal_base: Setting B1937+21_Rcvr_800_GUPPI_log10_ecorr to -6.44612
# INFO: enterprise.signals.signal_base: Setting B1937+21_S-wide_ASP_log10_ecorr to -6.56067
# INFO: enterprise.signals.signal_base: Setting B1937+21_S-wide_PUPPI_log10_ecorr to -6.79048
# INFO: enterprise.signals.signal_base: Setting B1937+21_red_noise_log10_A to -13.1687
# INFO: enterprise.signals.signal_base: Setting B1937+21_red_noise_gamma to 2.41503
# INFO: enterprise.signals.signal_base: Setting B1953+29_430_ASP_efac to 1.02334
# INFO: enterprise.signals.signal_base: Setting B1953+29_430_PUPPI_efac to 1.357
# INFO: enterprise.signals.signal_base: Setting B1953+29_L-wide_ASP_efac to 1.00909
# INFO: enterprise.signals.signal_base: Setting B1953+29_L-wide_PUPPI_efac to 1.07947
# INFO: enterprise.signals.signal_base: Setting B1953+29_430_ASP_log10_equad to -7.68958
# INFO: enterprise.signals.signal_base: Setting B1953+29_430_PUPPI_log10_equad to -7.71636
# INFO: enterprise.signals.signal_base: Setting B1953+29_L-wide_ASP_log10_equad to -7.98985
# INFO: enterprise.signals.signal_base: Setting B1953+29_L-wide_PUPPI_log10_equad to -7.98622
# INFO: enterprise.signals.signal_base: Setting B1953+29_430_ASP_log10_ecorr to -6.20285
# INFO: enterprise.signals.signal_base: Setting B1953+29_430_PUPPI_log10_ecorr to -6.17491
# INFO: enterprise.signals.signal_base: Setting B1953+29_L-wide_ASP_log10_ecorr to -7.21971
# INFO: enterprise.signals.signal_base: Setting B1953+29_L-wide_PUPPI_log10_ecorr to -7.16559
# INFO: enterprise.signals.signal_base: Setting B1953+29_red_noise_log10_A to -13.7442
# INFO: enterprise.signals.signal_base: Setting B1953+29_red_noise_gamma to 5.12646
# INFO: enterprise.signals.signal_base: Setting J0023+0923_430_ASP_efac to 1.03662
# INFO: enterprise.signals.signal_base: Setting J0023+0923_430_PUPPI_efac to 0.986704
# INFO: enterprise.signals.signal_base: Setting J0023+0923_L-wide_ASP_efac to 1.1745
# INFO: enterprise.signals.signal_base: Setting J0023+0923_L-wide_PUPPI_efac to 1.30208
# INFO: enterprise.signals.signal_base: Setting J0023+0923_430_ASP_log10_equad to -8.36052
# INFO: enterprise.signals.signal_base: Setting J0023+0923_430_PUPPI_log10_equad to -8.50979
# INFO: enterprise.signals.signal_base: Setting J0023+0923_L-wide_ASP_log10_equad to -7.68848
# INFO: enterprise.signals.signal_base: Setting J0023+0923_L-wide_PUPPI_log10_equad to -8.23718
# INFO: enterprise.signals.signal_base: Setting J0023+0923_430_ASP_log10_ecorr to -7.2878
# INFO: enterprise.signals.signal_base: Setting J0023+0923_430_PUPPI_log10_ecorr to -7.5305
# INFO: enterprise.signals.signal_base: Setting J0023+0923_L-wide_ASP_log10_ecorr to -7.03185
# INFO: enterprise.signals.signal_base: Setting J0023+0923_L-wide_PUPPI_log10_ecorr to -7.79718
# INFO: enterprise.signals.signal_base: Setting J0023+0923_red_noise_log10_A to -13.0535
# INFO: enterprise.signals.signal_base: Setting J0023+0923_red_noise_gamma to 0.918876
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_ASP_efac to 1.13871
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_PUPPI_efac to 0.917359
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_ASP_efac to 1.12336
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_PUPPI_efac to 1.14101
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_ASP_log10_equad to -8.27762
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_PUPPI_log10_equad to -5.94568
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_ASP_log10_equad to -8.17663
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_PUPPI_log10_equad to -6.67303
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_ASP_log10_ecorr to -7.6001
# INFO: enterprise.signals.signal_base: Setting J0030+0451_430_PUPPI_log10_ecorr to -7.11084
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_ASP_log10_ecorr to -7.59912
# INFO: enterprise.signals.signal_base: Setting J0030+0451_L-wide_PUPPI_log10_ecorr to -7.64239
# INFO: enterprise.signals.signal_base: Setting J0030+0451_red_noise_log10_A to -14.412
# INFO: enterprise.signals.signal_base: Setting J0030+0451_red_noise_gamma to 5.05806
# INFO: enterprise.signals.signal_base: Setting J0340+4130_Rcvr1_2_GUPPI_efac to 1.16242
# INFO: enterprise.signals.signal_base: Setting J0340+4130_Rcvr_800_GUPPI_efac to 1.09274
# INFO: enterprise.signals.signal_base: Setting J0340+4130_Rcvr1_2_GUPPI_log10_equad to -8.19297
# INFO: enterprise.signals.signal_base: Setting J0340+4130_Rcvr_800_GUPPI_log10_equad to -8.06619
# INFO: enterprise.signals.signal_base: Setting J0340+4130_Rcvr1_2_GUPPI_log10_ecorr to -7.46998
# INFO: enterprise.signals.signal_base: Setting J0340+4130_Rcvr_800_GUPPI_log10_ecorr to -7.31966
# INFO: enterprise.signals.signal_base: Setting J0340+4130_red_noise_log10_A to -16.1446
# INFO: enterprise.signals.signal_base: Setting J0340+4130_red_noise_gamma to 3.64906
# INFO: enterprise.signals.signal_base: Setting J0613-0200_Rcvr1_2_GASP_efac to 1.08413
# INFO: enterprise.signals.signal_base: Setting J0613-0200_Rcvr1_2_GUPPI_efac to 1.08569
# INFO: enterprise.signals.signal_base: Setting J0613-0200_Rcvr_800_GASP_efac to 1.09303
# INFO: enterprise.signals.signal_base: Setting J0613-0200_Rcvr_800_GUPPI_efac to 1.19709
# INFO: enterprise.signals.signal_base: Setting J0613-0200_Rcvr1_2_GASP_log10_equad to -8.29172
# INFO: enterprise.signals.signal_base: Setting J0613-0200_Rcvr1_2_GUPPI_log10_equad to -8.39354
# INFO: enterprise.signals.signal_base: Setting J0613-0200_Rcvr_800_GASP_log10_equad to -8.34563
# INFO: enterprise.signals.signal_base: Setting J0613-0200_Rcvr_800_GUPPI_log10_equad to -6.52894
# INFO: enterprise.signals.signal_base: Setting J0613-0200_Rcvr1_2_GASP_log10_ecorr to -7.51539
# INFO: enterprise.signals.signal_base: Setting J0613-0200_Rcvr1_2_GUPPI_log10_ecorr to -7.78395
# INFO: enterprise.signals.signal_base: Setting J0613-0200_Rcvr_800_GASP_log10_ecorr to -7.72404
# INFO: enterprise.signals.signal_base: Setting J0613-0200_Rcvr_800_GUPPI_log10_ecorr to -7.53941
# INFO: enterprise.signals.signal_base: Setting J0613-0200_red_noise_log10_A to -13.6168
# INFO: enterprise.signals.signal_base: Setting J0613-0200_red_noise_gamma to 3.16059
# INFO: enterprise.signals.signal_base: Setting J0645+5158_Rcvr1_2_GUPPI_efac to 1.1108
# INFO: enterprise.signals.signal_base: Setting J0645+5158_Rcvr_800_GUPPI_efac to 1.01848
# INFO: enterprise.signals.signal_base: Setting J0645+5158_Rcvr1_2_GUPPI_log10_equad to -8.49118
# INFO: enterprise.signals.signal_base: Setting J0645+5158_Rcvr_800_GUPPI_log10_equad to -7.11125
# INFO: enterprise.signals.signal_base: Setting J0645+5158_Rcvr1_2_GUPPI_log10_ecorr to -7.69595
# INFO: enterprise.signals.signal_base: Setting J0645+5158_Rcvr_800_GUPPI_log10_ecorr to -7.64942
# INFO: enterprise.signals.signal_base: Setting J0645+5158_red_noise_log10_A to -16.594
# INFO: enterprise.signals.signal_base: Setting J0645+5158_red_noise_gamma to 3.5116
# INFO: enterprise.signals.signal_base: Setting J0931-1902_Rcvr1_2_GUPPI_efac to 1.01275
# INFO: enterprise.signals.signal_base: Setting J0931-1902_Rcvr_800_GUPPI_efac to 1.18791
# INFO: enterprise.signals.signal_base: Setting J0931-1902_Rcvr1_2_GUPPI_log10_equad to -8.17571
# INFO: enterprise.signals.signal_base: Setting J0931-1902_Rcvr_800_GUPPI_log10_equad to -8.10688
# INFO: enterprise.signals.signal_base: Setting J0931-1902_Rcvr1_2_GUPPI_log10_ecorr to -7.33819
# INFO: enterprise.signals.signal_base: Setting J0931-1902_Rcvr_800_GUPPI_log10_ecorr to -7.21171
# INFO: enterprise.signals.signal_base: Setting J0931-1902_red_noise_log10_A to -15.7715
# INFO: enterprise.signals.signal_base: Setting J0931-1902_red_noise_gamma to 3.64212
# INFO: enterprise.signals.signal_base: Setting J1012+5307_Rcvr1_2_GASP_efac to 1.05234
# INFO: enterprise.signals.signal_base: Setting J1012+5307_Rcvr1_2_GUPPI_efac to 1.08498
# INFO: enterprise.signals.signal_base: Setting J1012+5307_Rcvr_800_GASP_efac to 1.11456
# INFO: enterprise.signals.signal_base: Setting J1012+5307_Rcvr_800_GUPPI_efac to 1.17272
# INFO: enterprise.signals.signal_base: Setting J1012+5307_Rcvr1_2_GASP_log10_equad to -8.04958
# INFO: enterprise.signals.signal_base: Setting J1012+5307_Rcvr1_2_GUPPI_log10_equad to -6.42345
# INFO: enterprise.signals.signal_base: Setting J1012+5307_Rcvr_800_GASP_log10_equad to -7.92351
# INFO: enterprise.signals.signal_base: Setting J1012+5307_Rcvr_800_GUPPI_log10_equad to -6.31253
# INFO: enterprise.signals.signal_base: Setting J1012+5307_Rcvr1_2_GASP_log10_ecorr to -7.27863
# INFO: enterprise.signals.signal_base: Setting J1012+5307_Rcvr1_2_GUPPI_log10_ecorr to -6.68714
# INFO: enterprise.signals.signal_base: Setting J1012+5307_Rcvr_800_GASP_log10_ecorr to -7.63389
# INFO: enterprise.signals.signal_base: Setting J1012+5307_Rcvr_800_GUPPI_log10_ecorr to -7.75432
# INFO: enterprise.signals.signal_base: Setting J1012+5307_red_noise_log10_A to -12.6189
# INFO: enterprise.signals.signal_base: Setting J1012+5307_red_noise_gamma to 1.02018
# INFO: enterprise.signals.signal_base: Setting J1024-0719_Rcvr1_2_GASP_efac to 0.923661
# INFO: enterprise.signals.signal_base: Setting J1024-0719_Rcvr1_2_GUPPI_efac to 1.14266
# INFO: enterprise.signals.signal_base: Setting J1024-0719_Rcvr_800_GASP_efac to 1.01755
# INFO: enterprise.signals.signal_base: Setting J1024-0719_Rcvr_800_GUPPI_efac to 1.19071
# INFO: enterprise.signals.signal_base: Setting J1024-0719_Rcvr1_2_GASP_log10_equad to -7.54914
# INFO: enterprise.signals.signal_base: Setting J1024-0719_Rcvr1_2_GUPPI_log10_equad to -8.49668
# INFO: enterprise.signals.signal_base: Setting J1024-0719_Rcvr_800_GASP_log10_equad to -7.94691
# INFO: enterprise.signals.signal_base: Setting J1024-0719_Rcvr_800_GUPPI_log10_equad to -8.542
# INFO: enterprise.signals.signal_base: Setting J1024-0719_Rcvr1_2_GASP_log10_ecorr to -7.08522
# INFO: enterprise.signals.signal_base: Setting J1024-0719_Rcvr1_2_GUPPI_log10_ecorr to -7.00321
# INFO: enterprise.signals.signal_base: Setting J1024-0719_Rcvr_800_GASP_log10_ecorr to -6.96383
# INFO: enterprise.signals.signal_base: Setting J1024-0719_Rcvr_800_GUPPI_log10_ecorr to -7.29206
# INFO: enterprise.signals.signal_base: Setting J1024-0719_red_noise_log10_A to -16.2659
# INFO: enterprise.signals.signal_base: Setting J1024-0719_red_noise_gamma to 3.338
# INFO: enterprise.signals.signal_base: Setting J1455-3330_Rcvr1_2_GASP_efac to 1.12806
# INFO: enterprise.signals.signal_base: Setting J1455-3330_Rcvr1_2_GUPPI_efac to 1.32475
# INFO: enterprise.signals.signal_base: Setting J1455-3330_Rcvr_800_GASP_efac to 1.49365
# INFO: enterprise.signals.signal_base: Setting J1455-3330_Rcvr_800_GUPPI_efac to 1.35131
# INFO: enterprise.signals.signal_base: Setting J1455-3330_Rcvr1_2_GASP_log10_equad to -8.04522
# INFO: enterprise.signals.signal_base: Setting J1455-3330_Rcvr1_2_GUPPI_log10_equad to -8.37397
# INFO: enterprise.signals.signal_base: Setting J1455-3330_Rcvr_800_GASP_log10_equad to -8.08877
# INFO: enterprise.signals.signal_base: Setting J1455-3330_Rcvr_800_GUPPI_log10_equad to -8.40589
# INFO: enterprise.signals.signal_base: Setting J1455-3330_Rcvr1_2_GASP_log10_ecorr to -6.06065
# INFO: enterprise.signals.signal_base: Setting J1455-3330_Rcvr1_2_GUPPI_log10_ecorr to -7.56026
# INFO: enterprise.signals.signal_base: Setting J1455-3330_Rcvr_800_GASP_log10_ecorr to -7.24673
# INFO: enterprise.signals.signal_base: Setting J1455-3330_Rcvr_800_GUPPI_log10_ecorr to -7.35803
# INFO: enterprise.signals.signal_base: Setting J1455-3330_red_noise_log10_A to -16.752
# INFO: enterprise.signals.signal_base: Setting J1455-3330_red_noise_gamma to 3.28721
# INFO: enterprise.signals.signal_base: Setting J1600-3053_Rcvr1_2_GASP_efac to 1.13991
# INFO: enterprise.signals.signal_base: Setting J1600-3053_Rcvr1_2_GUPPI_efac to 1.05637
# INFO: enterprise.signals.signal_base: Setting J1600-3053_Rcvr_800_GASP_efac to 1.18543
# INFO: enterprise.signals.signal_base: Setting J1600-3053_Rcvr_800_GUPPI_efac to 1.12855
# INFO: enterprise.signals.signal_base: Setting J1600-3053_Rcvr1_2_GASP_log10_equad to -7.77574
# INFO: enterprise.signals.signal_base: Setting J1600-3053_Rcvr1_2_GUPPI_log10_equad to -8.31385
# INFO: enterprise.signals.signal_base: Setting J1600-3053_Rcvr_800_GASP_log10_equad to -8.07856
# INFO: enterprise.signals.signal_base: Setting J1600-3053_Rcvr_800_GUPPI_log10_equad to -8.09682
# INFO: enterprise.signals.signal_base: Setting J1600-3053_Rcvr1_2_GASP_log10_ecorr to -7.41423
# INFO: enterprise.signals.signal_base: Setting J1600-3053_Rcvr1_2_GUPPI_log10_ecorr to -6.78034
# INFO: enterprise.signals.signal_base: Setting J1600-3053_Rcvr_800_GASP_log10_ecorr to -7.42253
# INFO: enterprise.signals.signal_base: Setting J1600-3053_Rcvr_800_GUPPI_log10_ecorr to -6.3244
# INFO: enterprise.signals.signal_base: Setting J1600-3053_red_noise_log10_A to -16.9777
# INFO: enterprise.signals.signal_base: Setting J1600-3053_red_noise_gamma to 3.13292
# INFO: enterprise.signals.signal_base: Setting J1614-2230_Rcvr1_2_GASP_efac to 1.15849
# INFO: enterprise.signals.signal_base: Setting J1614-2230_Rcvr1_2_GUPPI_efac to 1.06146
# INFO: enterprise.signals.signal_base: Setting J1614-2230_Rcvr_800_GASP_efac to 0.915636
# INFO: enterprise.signals.signal_base: Setting J1614-2230_Rcvr_800_GUPPI_efac to 1.01366
# INFO: enterprise.signals.signal_base: Setting J1614-2230_Rcvr1_2_GASP_log10_equad to -8.02865
# INFO: enterprise.signals.signal_base: Setting J1614-2230_Rcvr1_2_GUPPI_log10_equad to -8.53141
# INFO: enterprise.signals.signal_base: Setting J1614-2230_Rcvr_800_GASP_log10_equad to -8.01389
# INFO: enterprise.signals.signal_base: Setting J1614-2230_Rcvr_800_GUPPI_log10_equad to -8.34908
# INFO: enterprise.signals.signal_base: Setting J1614-2230_Rcvr1_2_GASP_log10_ecorr to -7.13589
# INFO: enterprise.signals.signal_base: Setting J1614-2230_Rcvr1_2_GUPPI_log10_ecorr to -7.63
# INFO: enterprise.signals.signal_base: Setting J1614-2230_Rcvr_800_GASP_log10_ecorr to -7.13582
# INFO: enterprise.signals.signal_base: Setting J1614-2230_Rcvr_800_GUPPI_log10_ecorr to -6.78123
# INFO: enterprise.signals.signal_base: Setting J1614-2230_red_noise_log10_A to -16.9988
# INFO: enterprise.signals.signal_base: Setting J1614-2230_red_noise_gamma to 3.31971
# INFO: enterprise.signals.signal_base: Setting J1640+2224_430_ASP_efac to 1.18797
# INFO: enterprise.signals.signal_base: Setting J1640+2224_430_PUPPI_efac to 1.13544
# INFO: enterprise.signals.signal_base: Setting J1640+2224_L-wide_ASP_efac to 1.07335
# INFO: enterprise.signals.signal_base: Setting J1640+2224_L-wide_PUPPI_efac to 1.25304
# INFO: enterprise.signals.signal_base: Setting J1640+2224_430_ASP_log10_equad to -6.26644
# INFO: enterprise.signals.signal_base: Setting J1640+2224_430_PUPPI_log10_equad to -7.48076
# INFO: enterprise.signals.signal_base: Setting J1640+2224_L-wide_ASP_log10_equad to -8.40253
# INFO: enterprise.signals.signal_base: Setting J1640+2224_L-wide_PUPPI_log10_equad to -8.61952
# INFO: enterprise.signals.signal_base: Setting J1640+2224_430_ASP_log10_ecorr to -7.75415
# INFO: enterprise.signals.signal_base: Setting J1640+2224_430_PUPPI_log10_ecorr to -7.0865
# INFO: enterprise.signals.signal_base: Setting J1640+2224_L-wide_ASP_log10_ecorr to -6.38835
# INFO: enterprise.signals.signal_base: Setting J1640+2224_L-wide_PUPPI_log10_ecorr to -7.67906
# INFO: enterprise.signals.signal_base: Setting J1640+2224_red_noise_log10_A to -17.0642
# INFO: enterprise.signals.signal_base: Setting J1640+2224_red_noise_gamma to 3.21169
# INFO: enterprise.signals.signal_base: Setting J1643-1224_Rcvr1_2_GASP_efac to 1.02956
# INFO: enterprise.signals.signal_base: Setting J1643-1224_Rcvr1_2_GUPPI_efac to 1.17092
# INFO: enterprise.signals.signal_base: Setting J1643-1224_Rcvr_800_GASP_efac to 1.48238
# INFO: enterprise.signals.signal_base: Setting J1643-1224_Rcvr_800_GUPPI_efac to 1.11174
# INFO: enterprise.signals.signal_base: Setting J1643-1224_Rcvr1_2_GASP_log10_equad to -8.02482
# INFO: enterprise.signals.signal_base: Setting J1643-1224_Rcvr1_2_GUPPI_log10_equad to -8.09463
# INFO: enterprise.signals.signal_base: Setting J1643-1224_Rcvr_800_GASP_log10_equad to -7.95054
# INFO: enterprise.signals.signal_base: Setting J1643-1224_Rcvr_800_GUPPI_log10_equad to -5.87069
# INFO: enterprise.signals.signal_base: Setting J1643-1224_Rcvr1_2_GASP_log10_ecorr to -7.44338
# INFO: enterprise.signals.signal_base: Setting J1643-1224_Rcvr1_2_GUPPI_log10_ecorr to -7.56453
# INFO: enterprise.signals.signal_base: Setting J1643-1224_Rcvr_800_GASP_log10_ecorr to -6.81804
# INFO: enterprise.signals.signal_base: Setting J1643-1224_Rcvr_800_GUPPI_log10_ecorr to -5.53303
# INFO: enterprise.signals.signal_base: Setting J1643-1224_red_noise_log10_A to -12.3588
# INFO: enterprise.signals.signal_base: Setting J1643-1224_red_noise_gamma to 1.83816
# INFO: enterprise.signals.signal_base: Setting J1713+0747_L-wide_ASP_efac to 1.02902
# INFO: enterprise.signals.signal_base: Setting J1713+0747_L-wide_PUPPI_efac to 1.1659
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr1_2_GASP_efac to 1.0879
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr1_2_GUPPI_efac to 1.19878
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GASP_efac to 1.19524
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GUPPI_efac to 1.06403
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_ASP_efac to 1.12282
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_PUPPI_efac to 1.08004
# INFO: enterprise.signals.signal_base: Setting J1713+0747_L-wide_ASP_log10_equad to -7.59213
# INFO: enterprise.signals.signal_base: Setting J1713+0747_L-wide_PUPPI_log10_equad to -8.90685
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr1_2_GASP_log10_equad to -8.17586
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr1_2_GUPPI_log10_equad to -8.29277
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GASP_log10_equad to -8.365
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GUPPI_log10_equad to -8.30246
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_ASP_log10_equad to -8.7862
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_PUPPI_log10_equad to -7.29251
# INFO: enterprise.signals.signal_base: Setting J1713+0747_L-wide_ASP_log10_ecorr to -6.96775
# INFO: enterprise.signals.signal_base: Setting J1713+0747_L-wide_PUPPI_log10_ecorr to -7.00729
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr1_2_GASP_log10_ecorr to -7.21635
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr1_2_GUPPI_log10_ecorr to -7.23259
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GASP_log10_ecorr to -7.76923
# INFO: enterprise.signals.signal_base: Setting J1713+0747_Rcvr_800_GUPPI_log10_ecorr to -6.70639
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_ASP_log10_ecorr to -6.95628
# INFO: enterprise.signals.signal_base: Setting J1713+0747_S-wide_PUPPI_log10_ecorr to -6.94551
# INFO: enterprise.signals.signal_base: Setting J1713+0747_red_noise_log10_A to -19.1114
# INFO: enterprise.signals.signal_base: Setting J1713+0747_red_noise_gamma to 1.7124
# INFO: enterprise.signals.signal_base: Setting J1738+0333_L-wide_ASP_efac to 1.14947
# INFO: enterprise.signals.signal_base: Setting J1738+0333_L-wide_PUPPI_efac to 1.15681
# INFO: enterprise.signals.signal_base: Setting J1738+0333_S-wide_ASP_efac to 0.943157
# INFO: enterprise.signals.signal_base: Setting J1738+0333_S-wide_PUPPI_efac to 1.04942
# INFO: enterprise.signals.signal_base: Setting J1738+0333_L-wide_ASP_log10_equad to -8.31894
# INFO: enterprise.signals.signal_base: Setting J1738+0333_L-wide_PUPPI_log10_equad to -8.18247
# INFO: enterprise.signals.signal_base: Setting J1738+0333_S-wide_ASP_log10_equad to -8.32135
# INFO: enterprise.signals.signal_base: Setting J1738+0333_S-wide_PUPPI_log10_equad to -8.38834
# INFO: enterprise.signals.signal_base: Setting J1738+0333_L-wide_ASP_log10_ecorr to -7.17249
# INFO: enterprise.signals.signal_base: Setting J1738+0333_L-wide_PUPPI_log10_ecorr to -7.47499
# INFO: enterprise.signals.signal_base: Setting J1738+0333_S-wide_ASP_log10_ecorr to -7.42056
# INFO: enterprise.signals.signal_base: Setting J1738+0333_S-wide_PUPPI_log10_ecorr to -7.56587
# INFO: enterprise.signals.signal_base: Setting J1738+0333_red_noise_log10_A to -16.5881
# INFO: enterprise.signals.signal_base: Setting J1738+0333_red_noise_gamma to 3.43076
# INFO: enterprise.signals.signal_base: Setting J1741+1351_430_ASP_efac to 0.92739
# INFO: enterprise.signals.signal_base: Setting J1741+1351_430_PUPPI_efac to 1.08265
# INFO: enterprise.signals.signal_base: Setting J1741+1351_L-wide_ASP_efac to 1.03545
# INFO: enterprise.signals.signal_base: Setting J1741+1351_L-wide_PUPPI_efac to 1.05026
# INFO: enterprise.signals.signal_base: Setting J1741+1351_430_ASP_log10_equad to -7.81532
# INFO: enterprise.signals.signal_base: Setting J1741+1351_430_PUPPI_log10_equad to -7.8145
# INFO: enterprise.signals.signal_base: Setting J1741+1351_L-wide_ASP_log10_equad to -8.31889
# INFO: enterprise.signals.signal_base: Setting J1741+1351_L-wide_PUPPI_log10_equad to -8.06543
# INFO: enterprise.signals.signal_base: Setting J1741+1351_430_ASP_log10_ecorr to -5.26368
# INFO: enterprise.signals.signal_base: Setting J1741+1351_430_PUPPI_log10_ecorr to -7.35363
# INFO: enterprise.signals.signal_base: Setting J1741+1351_L-wide_ASP_log10_ecorr to -7.15877
# INFO: enterprise.signals.signal_base: Setting J1741+1351_L-wide_PUPPI_log10_ecorr to -7.31138
# INFO: enterprise.signals.signal_base: Setting J1741+1351_red_noise_log10_A to -16.9121
# INFO: enterprise.signals.signal_base: Setting J1741+1351_red_noise_gamma to 3.38453
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr1_2_GASP_efac to 1.02696
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr1_2_GUPPI_efac to 1.21601
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr_800_GASP_efac to 1.16982
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr_800_GUPPI_efac to 1.04852
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr1_2_GASP_log10_equad to -6.83644
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr1_2_GUPPI_log10_equad to -6.73425
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr_800_GASP_log10_equad to -6.47133
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr_800_GUPPI_log10_equad to -6.5577
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr1_2_GASP_log10_ecorr to -6.3269
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr1_2_GUPPI_log10_ecorr to -6.45387
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr_800_GASP_log10_ecorr to -6.84423
# INFO: enterprise.signals.signal_base: Setting J1744-1134_Rcvr_800_GUPPI_log10_ecorr to -6.57852
# INFO: enterprise.signals.signal_base: Setting J1744-1134_red_noise_log10_A to -15.6471
# INFO: enterprise.signals.signal_base: Setting J1744-1134_red_noise_gamma to 3.30492
# INFO: enterprise.signals.signal_base: Setting J1747-4036_Rcvr1_2_GUPPI_efac to 1.13577
# INFO: enterprise.signals.signal_base: Setting J1747-4036_Rcvr_800_GUPPI_efac to 1.10483
# INFO: enterprise.signals.signal_base: Setting J1747-4036_Rcvr1_2_GUPPI_log10_equad to -7.85137
# INFO: enterprise.signals.signal_base: Setting J1747-4036_Rcvr_800_GUPPI_log10_equad to -7.65963
# INFO: enterprise.signals.signal_base: Setting J1747-4036_Rcvr1_2_GUPPI_log10_ecorr to -6.94614
# INFO: enterprise.signals.signal_base: Setting J1747-4036_Rcvr_800_GUPPI_log10_ecorr to -5.6511
# INFO: enterprise.signals.signal_base: Setting J1747-4036_red_noise_log10_A to -15.6499
# INFO: enterprise.signals.signal_base: Setting J1747-4036_red_noise_gamma to 3.29626
# INFO: enterprise.signals.signal_base: Setting J1832-0836_Rcvr1_2_GUPPI_efac to 1.04
# INFO: enterprise.signals.signal_base: Setting J1832-0836_Rcvr_800_GUPPI_efac to 1.05015
# INFO: enterprise.signals.signal_base: Setting J1832-0836_Rcvr1_2_GUPPI_log10_equad to -8.11201
# INFO: enterprise.signals.signal_base: Setting J1832-0836_Rcvr_800_GUPPI_log10_equad to -7.99132
# INFO: enterprise.signals.signal_base: Setting J1832-0836_Rcvr1_2_GUPPI_log10_ecorr to -7.62167
# INFO: enterprise.signals.signal_base: Setting J1832-0836_Rcvr_800_GUPPI_log10_ecorr to -7.38569
# INFO: enterprise.signals.signal_base: Setting J1832-0836_red_noise_log10_A to -16.0991
# INFO: enterprise.signals.signal_base: Setting J1832-0836_red_noise_gamma to 3.69834
# INFO: enterprise.signals.signal_base: Setting J1853+1303_430_ASP_efac to 1.10259
# INFO: enterprise.signals.signal_base: Setting J1853+1303_430_PUPPI_efac to 1.07243
# INFO: enterprise.signals.signal_base: Setting J1853+1303_L-wide_ASP_efac to 1.14229
# INFO: enterprise.signals.signal_base: Setting J1853+1303_L-wide_PUPPI_efac to 1.14701
# INFO: enterprise.signals.signal_base: Setting J1853+1303_430_ASP_log10_equad to -7.82376
# INFO: enterprise.signals.signal_base: Setting J1853+1303_430_PUPPI_log10_equad to -8.01381
# INFO: enterprise.signals.signal_base: Setting J1853+1303_L-wide_ASP_log10_equad to -8.3849
# INFO: enterprise.signals.signal_base: Setting J1853+1303_L-wide_PUPPI_log10_equad to -8.44421
# INFO: enterprise.signals.signal_base: Setting J1853+1303_430_ASP_log10_ecorr to -6.74256
# INFO: enterprise.signals.signal_base: Setting J1853+1303_430_PUPPI_log10_ecorr to -6.96278
# INFO: enterprise.signals.signal_base: Setting J1853+1303_L-wide_ASP_log10_ecorr to -7.48808
# INFO: enterprise.signals.signal_base: Setting J1853+1303_L-wide_PUPPI_log10_ecorr to -7.55986
# INFO: enterprise.signals.signal_base: Setting J1853+1303_red_noise_log10_A to -16.8149
# INFO: enterprise.signals.signal_base: Setting J1853+1303_red_noise_gamma to 3.39717
# INFO: enterprise.signals.signal_base: Setting J1903+0327_L-wide_ASP_efac to 1.18369
# INFO: enterprise.signals.signal_base: Setting J1903+0327_L-wide_PUPPI_efac to 1.17902
# INFO: enterprise.signals.signal_base: Setting J1903+0327_S-wide_ASP_efac to 0.829733
# INFO: enterprise.signals.signal_base: Setting J1903+0327_S-wide_PUPPI_efac to 1.11616
# INFO: enterprise.signals.signal_base: Setting J1903+0327_L-wide_ASP_log10_equad to -7.88745
# INFO: enterprise.signals.signal_base: Setting J1903+0327_L-wide_PUPPI_log10_equad to -8.33935
# INFO: enterprise.signals.signal_base: Setting J1903+0327_S-wide_ASP_log10_equad to -7.23985
# INFO: enterprise.signals.signal_base: Setting J1903+0327_S-wide_PUPPI_log10_equad to -8.27574
# INFO: enterprise.signals.signal_base: Setting J1903+0327_L-wide_ASP_log10_ecorr to -7.09891
# INFO: enterprise.signals.signal_base: Setting J1903+0327_L-wide_PUPPI_log10_ecorr to -5.85787
# INFO: enterprise.signals.signal_base: Setting J1903+0327_S-wide_ASP_log10_ecorr to -7.20923
# INFO: enterprise.signals.signal_base: Setting J1903+0327_S-wide_PUPPI_log10_ecorr to -7.3829
# INFO: enterprise.signals.signal_base: Setting J1903+0327_red_noise_log10_A to -12.6797
# INFO: enterprise.signals.signal_base: Setting J1903+0327_red_noise_gamma to 3.49165
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr1_2_GASP_efac to 0.986438
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr1_2_GUPPI_efac to 1.03462
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr_800_GASP_efac to 0.985523
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr_800_GUPPI_efac to 1.05208
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr1_2_GASP_log10_equad to -7.97229
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr1_2_GUPPI_log10_equad to -8.31285
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr_800_GASP_log10_equad to -6.6358
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr_800_GUPPI_log10_equad to -7.43842
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr1_2_GASP_log10_ecorr to -8.00662
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr1_2_GUPPI_log10_ecorr to -7.13828
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr_800_GASP_log10_ecorr to -7.86032
# INFO: enterprise.signals.signal_base: Setting J1909-3744_Rcvr_800_GUPPI_log10_ecorr to -7.14764
# INFO: enterprise.signals.signal_base: Setting J1909-3744_red_noise_log10_A to -15.1073
# INFO: enterprise.signals.signal_base: Setting J1909-3744_red_noise_gamma to 2.88933
# INFO: enterprise.signals.signal_base: Setting J1910+1256_L-wide_ASP_efac to 1.10531
# INFO: enterprise.signals.signal_base: Setting J1910+1256_L-wide_PUPPI_efac to 1.24233
# INFO: enterprise.signals.signal_base: Setting J1910+1256_S-wide_ASP_efac to 0.968699
# INFO: enterprise.signals.signal_base: Setting J1910+1256_S-wide_PUPPI_efac to 1.30504
# INFO: enterprise.signals.signal_base: Setting J1910+1256_L-wide_ASP_log10_equad to -7.92206
# INFO: enterprise.signals.signal_base: Setting J1910+1256_L-wide_PUPPI_log10_equad to -8.45637
# INFO: enterprise.signals.signal_base: Setting J1910+1256_S-wide_ASP_log10_equad to -6.89641
# INFO: enterprise.signals.signal_base: Setting J1910+1256_S-wide_PUPPI_log10_equad to -8.11634
# INFO: enterprise.signals.signal_base: Setting J1910+1256_L-wide_ASP_log10_ecorr to -5.90936
# INFO: enterprise.signals.signal_base: Setting J1910+1256_L-wide_PUPPI_log10_ecorr to -6.63821
# INFO: enterprise.signals.signal_base: Setting J1910+1256_S-wide_ASP_log10_ecorr to -7.3283
# INFO: enterprise.signals.signal_base: Setting J1910+1256_S-wide_PUPPI_log10_ecorr to -6.41078
# INFO: enterprise.signals.signal_base: Setting J1910+1256_red_noise_log10_A to -12.5874
# INFO: enterprise.signals.signal_base: Setting J1910+1256_red_noise_gamma to 2.18217
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr1_2_GASP_efac to 1.03139
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr1_2_GUPPI_efac to 1.09892
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr_800_GASP_efac to 1.05461
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr_800_GUPPI_efac to 1.09148
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr1_2_GASP_log10_equad to -8.39359
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr1_2_GUPPI_log10_equad to -8.20206
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr_800_GASP_log10_equad to -7.9677
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr_800_GUPPI_log10_equad to -8.4117
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr1_2_GASP_log10_ecorr to -7.3475
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr1_2_GUPPI_log10_ecorr to -7.37082
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr_800_GASP_log10_ecorr to -7.55392
# INFO: enterprise.signals.signal_base: Setting J1918-0642_Rcvr_800_GUPPI_log10_ecorr to -7.18419
# INFO: enterprise.signals.signal_base: Setting J1918-0642_red_noise_log10_A to -16.8325
# INFO: enterprise.signals.signal_base: Setting J1918-0642_red_noise_gamma to 3.21288
# INFO: enterprise.signals.signal_base: Setting J1923+2515_430_ASP_efac to 1.26185
# INFO: enterprise.signals.signal_base: Setting J1923+2515_430_PUPPI_efac to 1.07883
# INFO: enterprise.signals.signal_base: Setting J1923+2515_L-wide_ASP_efac to 0.912005
# INFO: enterprise.signals.signal_base: Setting J1923+2515_L-wide_PUPPI_efac to 1.3298
# INFO: enterprise.signals.signal_base: Setting J1923+2515_430_ASP_log10_equad to -7.87926
# INFO: enterprise.signals.signal_base: Setting J1923+2515_430_PUPPI_log10_equad to -8.06353
# INFO: enterprise.signals.signal_base: Setting J1923+2515_L-wide_ASP_log10_equad to -8.31
# INFO: enterprise.signals.signal_base: Setting J1923+2515_L-wide_PUPPI_log10_equad to -7.70616
# INFO: enterprise.signals.signal_base: Setting J1923+2515_430_ASP_log10_ecorr to -5.83454
# INFO: enterprise.signals.signal_base: Setting J1923+2515_430_PUPPI_log10_ecorr to -6.81479
# INFO: enterprise.signals.signal_base: Setting J1923+2515_L-wide_ASP_log10_ecorr to -6.38894
# INFO: enterprise.signals.signal_base: Setting J1923+2515_L-wide_PUPPI_log10_ecorr to -7.38332
# INFO: enterprise.signals.signal_base: Setting J1923+2515_red_noise_log10_A to -16.3272
# INFO: enterprise.signals.signal_base: Setting J1923+2515_red_noise_gamma to 3.51969
# INFO: enterprise.signals.signal_base: Setting J1944+0907_430_ASP_efac to 1.09559
# INFO: enterprise.signals.signal_base: Setting J1944+0907_430_PUPPI_efac to 1.19833
# INFO: enterprise.signals.signal_base: Setting J1944+0907_L-wide_ASP_efac to 1.39437
# INFO: enterprise.signals.signal_base: Setting J1944+0907_L-wide_PUPPI_efac to 1.39417
# INFO: enterprise.signals.signal_base: Setting J1944+0907_430_ASP_log10_equad to -7.95891
# INFO: enterprise.signals.signal_base: Setting J1944+0907_430_PUPPI_log10_equad to -8.05202
# INFO: enterprise.signals.signal_base: Setting J1944+0907_L-wide_ASP_log10_equad to -7.88786
# INFO: enterprise.signals.signal_base: Setting J1944+0907_L-wide_PUPPI_log10_equad to -8.37225
# INFO: enterprise.signals.signal_base: Setting J1944+0907_430_ASP_log10_ecorr to -6.54216
# INFO: enterprise.signals.signal_base: Setting J1944+0907_430_PUPPI_log10_ecorr to -7.20542
# INFO: enterprise.signals.signal_base: Setting J1944+0907_L-wide_ASP_log10_ecorr to -6.06614
# INFO: enterprise.signals.signal_base: Setting J1944+0907_L-wide_PUPPI_log10_ecorr to -7.50644
# INFO: enterprise.signals.signal_base: Setting J1944+0907_red_noise_log10_A to -12.6064
# INFO: enterprise.signals.signal_base: Setting J1944+0907_red_noise_gamma to 3.15937
# INFO: enterprise.signals.signal_base: Setting J1949+3106_L-wide_PUPPI_efac to 1.0393
# INFO: enterprise.signals.signal_base: Setting J1949+3106_S-wide_PUPPI_efac to 1.0184
# INFO: enterprise.signals.signal_base: Setting J1949+3106_L-wide_PUPPI_log10_equad to -8.1197
# INFO: enterprise.signals.signal_base: Setting J1949+3106_S-wide_PUPPI_log10_equad to -7.78775
# INFO: enterprise.signals.signal_base: Setting J1949+3106_L-wide_PUPPI_log10_ecorr to -7.33396
# INFO: enterprise.signals.signal_base: Setting J1949+3106_S-wide_PUPPI_log10_ecorr to -6.90868
# INFO: enterprise.signals.signal_base: Setting J1949+3106_red_noise_log10_A to -15.9183
# INFO: enterprise.signals.signal_base: Setting J1949+3106_red_noise_gamma to 3.65469
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr1_2_GASP_efac to 0.967206
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr1_2_GUPPI_efac to 1.2128
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr_800_GASP_efac to 1.15777
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr_800_GUPPI_efac to 1.07888
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr1_2_GASP_log10_equad to -7.69017
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr1_2_GUPPI_log10_equad to -8.45324
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr_800_GASP_log10_equad to -7.92738
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr_800_GUPPI_log10_equad to -8.38299
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr1_2_GASP_log10_ecorr to -7.1519
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr1_2_GUPPI_log10_ecorr to -7.64287
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr_800_GASP_log10_ecorr to -7.2034
# INFO: enterprise.signals.signal_base: Setting J2010-1323_Rcvr_800_GUPPI_log10_ecorr to -7.63276
# INFO: enterprise.signals.signal_base: Setting J2010-1323_red_noise_log10_A to -16.4803
# INFO: enterprise.signals.signal_base: Setting J2010-1323_red_noise_gamma to 3.42768
# INFO: enterprise.signals.signal_base: Setting J2017+0603_430_PUPPI_efac to 1.0486
# INFO: enterprise.signals.signal_base: Setting J2017+0603_L-wide_PUPPI_efac to 1.15216
# INFO: enterprise.signals.signal_base: Setting J2017+0603_S-wide_ASP_efac to 0.861167
# INFO: enterprise.signals.signal_base: Setting J2017+0603_S-wide_PUPPI_efac to 1.26673
# INFO: enterprise.signals.signal_base: Setting J2017+0603_430_PUPPI_log10_equad to -8.09404
# INFO: enterprise.signals.signal_base: Setting J2017+0603_L-wide_PUPPI_log10_equad to -8.59392
# INFO: enterprise.signals.signal_base: Setting J2017+0603_S-wide_ASP_log10_equad to -7.65776
# INFO: enterprise.signals.signal_base: Setting J2017+0603_S-wide_PUPPI_log10_equad to -8.4567
# INFO: enterprise.signals.signal_base: Setting J2017+0603_430_PUPPI_log10_ecorr to -6.89376
# INFO: enterprise.signals.signal_base: Setting J2017+0603_L-wide_PUPPI_log10_ecorr to -7.79531
# INFO: enterprise.signals.signal_base: Setting J2017+0603_S-wide_ASP_log10_ecorr to -6.91793
# INFO: enterprise.signals.signal_base: Setting J2017+0603_S-wide_PUPPI_log10_ecorr to -7.6241
# INFO: enterprise.signals.signal_base: Setting J2017+0603_red_noise_log10_A to -16.389
# INFO: enterprise.signals.signal_base: Setting J2017+0603_red_noise_gamma to 3.63865
# INFO: enterprise.signals.signal_base: Setting J2043+1711_430_ASP_efac to 1.41609
# INFO: enterprise.signals.signal_base: Setting J2043+1711_430_PUPPI_efac to 1.08304
# INFO: enterprise.signals.signal_base: Setting J2043+1711_L-wide_ASP_efac to 1.17221
# INFO: enterprise.signals.signal_base: Setting J2043+1711_L-wide_PUPPI_efac to 1.13832
# INFO: enterprise.signals.signal_base: Setting J2043+1711_430_ASP_log10_equad to -8.15645
# INFO: enterprise.signals.signal_base: Setting J2043+1711_430_PUPPI_log10_equad to -6.64609
# INFO: enterprise.signals.signal_base: Setting J2043+1711_L-wide_ASP_log10_equad to -8.192
# INFO: enterprise.signals.signal_base: Setting J2043+1711_L-wide_PUPPI_log10_equad to -8.63939
# INFO: enterprise.signals.signal_base: Setting J2043+1711_430_ASP_log10_ecorr to -7.29294
# INFO: enterprise.signals.signal_base: Setting J2043+1711_430_PUPPI_log10_ecorr to -6.38509
# INFO: enterprise.signals.signal_base: Setting J2043+1711_L-wide_ASP_log10_ecorr to -7.3789
# INFO: enterprise.signals.signal_base: Setting J2043+1711_L-wide_PUPPI_log10_ecorr to -7.83727
# INFO: enterprise.signals.signal_base: Setting J2043+1711_red_noise_log10_A to -16.6752
# INFO: enterprise.signals.signal_base: Setting J2043+1711_red_noise_gamma to 3.50096
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr1_2_GASP_efac to 1.00043
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr1_2_GUPPI_efac to 1.09892
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr_800_GASP_efac to 1.50673
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr_800_GUPPI_efac to 1.12959
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr1_2_GASP_log10_equad to -5.70683
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr1_2_GUPPI_log10_equad to -6.28759
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr_800_GASP_log10_equad to -7.46919
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr_800_GUPPI_log10_equad to -6.32362
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr1_2_GASP_log10_ecorr to -6.72819
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr1_2_GUPPI_log10_ecorr to -6.32176
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr_800_GASP_log10_ecorr to -6.24509
# INFO: enterprise.signals.signal_base: Setting J2145-0750_Rcvr_800_GUPPI_log10_ecorr to -6.57986
# INFO: enterprise.signals.signal_base: Setting J2145-0750_red_noise_log10_A to -15.7129
# INFO: enterprise.signals.signal_base: Setting J2145-0750_red_noise_gamma to 2.67557
# INFO: enterprise.signals.signal_base: Setting J2214+3000_L-wide_ASP_efac to 0.701661
# INFO: enterprise.signals.signal_base: Setting J2214+3000_L-wide_PUPPI_efac to 1.40287
# INFO: enterprise.signals.signal_base: Setting J2214+3000_S-wide_ASP_efac to 0.968783
# INFO: enterprise.signals.signal_base: Setting J2214+3000_S-wide_PUPPI_efac to 1.13066
# INFO: enterprise.signals.signal_base: Setting J2214+3000_L-wide_ASP_log10_equad to -7.93961
# INFO: enterprise.signals.signal_base: Setting J2214+3000_L-wide_PUPPI_log10_equad to -8.34099
# INFO: enterprise.signals.signal_base: Setting J2214+3000_S-wide_ASP_log10_equad to -7.47918
# INFO: enterprise.signals.signal_base: Setting J2214+3000_S-wide_PUPPI_log10_equad to -5.81721
# INFO: enterprise.signals.signal_base: Setting J2214+3000_L-wide_ASP_log10_ecorr to -7.00296
# INFO: enterprise.signals.signal_base: Setting J2214+3000_L-wide_PUPPI_log10_ecorr to -7.51157
# INFO: enterprise.signals.signal_base: Setting J2214+3000_S-wide_ASP_log10_ecorr to -6.89832
# INFO: enterprise.signals.signal_base: Setting J2214+3000_S-wide_PUPPI_log10_ecorr to -6.83081
# INFO: enterprise.signals.signal_base: Setting J2214+3000_red_noise_log10_A to -16.1194
# INFO: enterprise.signals.signal_base: Setting J2214+3000_red_noise_gamma to 3.55294
# INFO: enterprise.signals.signal_base: Setting J2302+4442_Rcvr1_2_GUPPI_efac to 1.13146
# INFO: enterprise.signals.signal_base: Setting J2302+4442_Rcvr_800_GUPPI_efac to 1.03602
# INFO: enterprise.signals.signal_base: Setting J2302+4442_Rcvr1_2_GUPPI_log10_equad to -8.1143
# INFO: enterprise.signals.signal_base: Setting J2302+4442_Rcvr_800_GUPPI_log10_equad to -8.03307
# INFO: enterprise.signals.signal_base: Setting J2302+4442_Rcvr1_2_GUPPI_log10_ecorr to -6.83878
# INFO: enterprise.signals.signal_base: Setting J2302+4442_Rcvr_800_GUPPI_log10_ecorr to -7.06865
# INFO: enterprise.signals.signal_base: Setting J2302+4442_red_noise_log10_A to -13.439
# INFO: enterprise.signals.signal_base: Setting J2302+4442_red_noise_gamma to 3.18228
# INFO: enterprise.signals.signal_base: Setting J2317+1439_327_ASP_efac to 1.05869
# INFO: enterprise.signals.signal_base: Setting J2317+1439_327_PUPPI_efac to 1.14332
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_ASP_efac to 1.12607
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_PUPPI_efac to 1.04287
# INFO: enterprise.signals.signal_base: Setting J2317+1439_L-wide_PUPPI_efac to 0.954996
# INFO: enterprise.signals.signal_base: Setting J2317+1439_327_ASP_log10_equad to -6.41929
# INFO: enterprise.signals.signal_base: Setting J2317+1439_327_PUPPI_log10_equad to -6.39705
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_ASP_log10_equad to -6.92682
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_PUPPI_log10_equad to -6.4171
# INFO: enterprise.signals.signal_base: Setting J2317+1439_L-wide_PUPPI_log10_equad to -6.56296
# INFO: enterprise.signals.signal_base: Setting J2317+1439_327_ASP_log10_ecorr to -7.59726
# INFO: enterprise.signals.signal_base: Setting J2317+1439_327_PUPPI_log10_ecorr to -7.27493
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_ASP_log10_ecorr to -6.14458
# INFO: enterprise.signals.signal_base: Setting J2317+1439_430_PUPPI_log10_ecorr to -6.49356
# INFO: enterprise.signals.signal_base: Setting J2317+1439_L-wide_PUPPI_log10_ecorr to -7.59813
# INFO: enterprise.signals.signal_base: Setting J2317+1439_red_noise_log10_A to -17.129
# INFO: enterprise.signals.signal_base: Setting J2317+1439_red_noise_gamma to 3.25799

# %% [markdown]
# ########## FOR TESTING PURPOSES ONLY #################
#
# fpstat = 0.0
# f0 = 7e-8
# #Internals of Fstat for test pta
# TNrs = pta_test.get_TNr(xs_test)
# TNTs = pta_test.get_TNT(xs_test)
# phiinvs = pta_test.get_phiinv(xs_test, logdet=False, method='partition')
# Nvecs = pta_test.get_ndiag(xs_test)
# Ts = pta_test.get_basis(xs_test)
# Nmat = []
#
# for ii,p in enumerate(psrs):
#     phiinv, TNr, TNT, Nvec, T = phiinvs[ii], TNrs[ii], TNTs[ii], Nvecs[ii], Ts[ii]
#     Sigma = TNT + (np.diag(phiinv) if phiinv.ndim == 1 else phiinv)
#     cf = sl.cho_factor(Sigma)
#     #Put pulsar's autoerrors in a diagonal matrix
#     Ndiag = np.diag(1.0/Nvec)
#     Tt = np.transpose(T)
#     TtN = np.dot(Tt,Ndiag)
#     expval2 = sl.cho_solve(cf,TtN)
#     TtNt = np.transpose(TtN)
#
#     #An Ntoa by Ntoa noise matrix to be used in expand dense matrix calculations earlier
#     Nmat.append(Ndiag - np.dot(TtNt,expval2))
#
#     # define N vectors from Ellis et al, 2012 N_i=(x|A_i) for each pulsar
#     N = np.zeros(2)
#     # define M matrix M_ij=(A_i|A_j)
#     M = np.zeros((2, 2))
#
#     # Define A vector
#     A = np.zeros((2, len(p.toas)))
#     A[0,:] = f0**(-1./3.) * np.sin(2*f0*newtoas[ii])
#     A[1,:] = f0**(-1./3.) * np.cos(2*f0*newtoas[ii])
#
#     # define N vectors from Ellis et al, 2012 N_i=(r|A_i) for each pulsar
#     N = np.array([np.dot(A[0,:], np.dot(Nmat[ii],p.residuals)), \
#                       np.dot(A[1,:], np.dot(Nmat[ii],p.residuals))])
#
#     # define M matrix M_ij=(A_i|A_j)
#     for jj in range(2):
#         for kk in range(2):
#             M[jj,kk] = np.dot(A[jj,:], np.dot(Nmat[ii], A[kk,:]))
#
#     # take inverse of M
#     Minv = sl.pinv(M)
#
#     fpstat += 0.5 * np.dot(N, np.dot(Minv, N))
#
#
# print(fpstat)

# %%
# make sure all pulsar have same reference time
def GetRefTime(psrs):
    tt=[] 
    for p in psrs:
        tt.append(np.min(p.toas))

    # find reference time
    tref = np.min(tt)
    newtoas = []
    # now scale pulsar time
    for p in psrs:
        newtoas.append((p.toas - tref))
    return newtoas

# %%
########## FOR TESTING PURPOSES ONLY #################
num = 5
plt.scatter(psrs_full[num].toas,psrs_full[num].residuals)
plt.ylim([-2e-5,2e-5])
plt.show()

plt.scatter(GetRefTime(psrs_full)[num],psrs_full[num].residuals)
plt.ylim([-2e-5,2e-5])
plt.show()

# %% [markdown]
# ########## TAKES FOREVER TO RUN, USE ANDREWFPSTAT2 AND GETNMATRIX #################
# def AndrewFpstat(pta,psrs,params,f0):
#     '''Takes in the full pta, the pulsars that make up the pta
#     (Should make this a function in ptas to use self instead of pta?),
#     and the orbital frequency of the gravitational wave (usually the search parameter).
#     Returns the Fp statistic
#     '''
#
#     TNrs = pta.get_TNr(params)
#     TNTs = pta.get_TNT(params)
#     phiinvs = pta.get_phiinv(params, logdet=False, method='partition')
#
#     #Get noise parameters for pta toaerr**2
#     Nvecs = pta.get_ndiag(params)
#
#     Ts = pta.get_basis(params)
#     Nmat = []
#
#     # make sure all pulsar have same reference time
#     #Unsure if necessary
#     tt=[]
#     for p in psrs:
#         tt.append(np.min(p.toas))
#
#     # find reference time
#     tref = np.min(tt)
#     newtoas = []
#     # now scale pulsar time and convert to seconds
#     for p in psrs:
#         newtoas.append((p.toas - tref))
#
#     fpstat = 0.0
#
#     #Probably a better way of doing this as well, but using TNTs[ii] for example didn't work
#     for ii,p in enumerate(psrs):
#         phiinv, TNr, TNT, Nvec, T = phiinvs[ii], TNrs[ii], TNTs[ii], Nvecs[ii], Ts[ii]
#         Sigma = TNT + (np.diag(phiinv) if phiinv.ndim == 1 else phiinv)
#         cf = sl.cho_factor(Sigma)
#         #Put pulsar's autoerrors in a diagonal matrix
#         print(ii)
#         TtN = Nvec.solve(other = np.eye(np.shape(p.residuals)[0]),left_array = T)
#         Ndiag = Nvec.solve(other = np.eye(np.shape(p.residuals)[0]),left_array = np.eye(np.shape(p.residuals)[0]))
#
#         expval2 = sl.cho_solve(cf,TtN)
#         TtNt = np.transpose(TtN)
#
#         #An Ntoa by Ntoa noise matrix to be used in expand dense matrix calculations earlier
#         Nmat.append(Ndiag - np.dot(TtNt,expval2))
#
#         # define N vectors from Ellis et al, 2012 N_i=(x|A_i) for each pulsar
#         N = np.zeros(2)
#         # define M matrix M_ij=(A_i|A_j)
#         M = np.zeros((2, 2))
#
#         # Define A vector
#         A = np.zeros((2, len(p.toas)))
#         A[0,:] = f0**(-1./3.) * np.sin(2*np.pi*f0*newtoas[ii])
#         A[1,:] = f0**(-1./3.) * np.cos(2*np.pi*f0*newtoas[ii])
#
#         # define N vectors from Ellis et al, 2012 N_i=(r|A_i) for each pulsar
#         N = np.array([np.dot(A[0,:], np.dot(Nmat[ii],p.residuals)), \
#                       np.dot(A[1,:], np.dot(Nmat[ii],p.residuals))])
#
#         # define M matrix M_ij=(A_i|A_j)
#         for jj in range(2):
#             for kk in range(2):
#                 M[jj,kk] = np.dot(A[jj,:], np.dot(Nmat[ii], A[kk,:]))
#
#         # take inverse of M
#         Minv = sl.pinv(M)
#
#         fpstat += 0.5 * np.dot(N, np.dot(Minv, N))
#
#     return fpstat

# %%
def GenNmat(pta,params):
    '''Makes the Nmatrix used in the fstatistic'''
    TNTs = pta.get_TNT(params)
    phiinvs = pta.get_phiinv(params, logdet=False, method='partition') 
    #Get noise parameters for pta toaerr**2
    Nvecs = pta.get_ndiag(params)
    #Get the basis matrix
    Ts = pta.get_basis(params)
    Nmat = []
    print('Making Nmat')
    l1 = np.shape(TNTs)[0]
    i = 1
    
    for phiinv, TNT, Nvec, T in zip(phiinvs, TNTs, Nvecs, Ts):
        start = time.time()
        Sigma = TNT + (np.diag(phiinv) if phiinv.ndim == 1 else phiinv)
        cf = sl.cho_factor(Sigma)      
        Nshape = np.shape(T)[0]
        TtN = Nvec.solve(other = np.eye(Nshape),left_array = T)
        
        #Put pulsar's autoerrors in a diagonal matrix
        Ndiag = Nvec.solve(other = np.eye(Nshape),left_array = np.eye(Nshape))
    
        expval2 = sl.cho_solve(cf,TtN)
        #TtNt = np.transpose(TtN)
        
        #An Ntoa by Ntoa noise matrix to be used in expand dense matrix calculations earlier
        Nmat.append(Ndiag - np.dot(TtN.T,expval2))
        end = time.time()
        print(repr(i) + ' out of ' + repr(l1) + ' Done. Time: ' + repr(end-start))
        i += 1
    return Nmat

# %%
Nmat_test = GenNmat(pta_test,params_test)
# Out:
# Making Nmat
# 1 out of 2 Done. Time: 6.6691179275512695
# 2 out of 2 Done. Time: 404.57685899734497

# %%
#Making and saving Nmatrix so it doesn't need to be calculated again
Nmat_full = GenNmat(pta_full,params_full)
# Out:
# Making Nmat
# 1 out of 37 Done. Time: 28.268008947372437
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-a9675c3d9be8> in <module>
#       1 #Making and saving Nmatrix so it doesn't need to be calculated again
# ----> 2 Nmat_full = GenNmat(pta_full,params_full)
#
# <ipython-input-11-846586fe74b3> in GenNmat(pta, params)
#      20
#      21         #Put pulsar's autoerrors in a diagonal matrix
# ---> 22         Ndiag = Nvec.solve(other = np.eye(Nshape),left_array = np.eye(Nshape))
#      23
#      24         expval2 = sl.cho_solve(cf,TtN)
#
# ~/anaconda3/envs/enterprise/lib/python3.6/site-packages/enterprise/signals/signal_base.py in solve(self, other, left_array, logdet)
#    1170                 raise TypeError
#    1171             elif left_array is not None and left_array.ndim == 2:
# -> 1172                 ret = self._solve_2D2(other, left_array)
#    1173             elif left_array is not None and left_array.ndim == 1:
#    1174                 ret = np.dot(other.T, self._solve_D1(left_array))
#
# ~/anaconda3/envs/enterprise/lib/python3.6/site-packages/enterprise/signals/signal_base.py in _solve_2D2(self, X, Z)
#    1140                 zn = np.dot(niblock, Zblock)
#    1141                 xn = np.dot(niblock, Xblock)
# -> 1142                 ZNX -= beta * np.outer(zn.T, xn)
#    1143         return ZNX
#    1144
#
# KeyboardInterrupt:

# %%
def AndrewFpstat2(psrs,Nmat,aligned_toas,f0):
    '''Takes in the full pta, the pulsars that make up the pta 
    (Should make this a function in ptas to use self instead of pta?),
    and the orbital angular frequency of the gravitational wave (usually the search parameter).
    Returns the Fp statistic
    '''
    
    fpstat = 0.0
        
    for ii,p in enumerate(psrs):
        # define N vectors from Ellis et al, 2012 N_i=(x|A_i) for each pulsar
        N = np.zeros(2)
        # define M matrix M_ij=(A_i|A_j)
        M = np.zeros((2, 2))

        # Define A vector
        A = np.zeros((2, len(aligned_toas[ii])))
        A[0,:] = f0**(-1./3.) * np.sin(2*np.pi*f0*aligned_toas[ii])
        A[1,:] = f0**(-1./3.) * np.cos(2*np.pi*f0*aligned_toas[ii])
    
        # define N vectors from Ellis et al, 2012 N_i=(r|A_i) for each pulsar
        N = np.array([np.dot(A[0,:], np.dot(Nmat[ii],p.residuals)), \
                      np.dot(A[1,:], np.dot(Nmat[ii],p.residuals))]) 
        
        # define M matrix M_ij=(A_i|A_j)
        for jj in range(2):
            for kk in range(2):
                M[jj,kk] = np.dot(A[jj,:], np.dot(Nmat[ii], A[kk,:]))
        
        # take inverse of M
        Minv = sl.pinv(M)
        
        fpstat += 0.5 * np.dot(N, np.dot(Minv, N))
    return fpstat

# %%
f0_full = 1/Tspan_full
f0_test = 1/Tspan_test
print(f0_full)
print(f0_test)
# Out:
# 3.421256282315104e-09
# 3.4735783035525875e-09

# %%
newtoas_full = GetRefTime(psrs_full)
print(AndrewFpstat2(psrs_full,Nmat_full,newtoas_full,f0_full))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-8ffcf17f1376> in <module>
# ----> 1 newtoas_full = GetRefTime(psrs_full)
#       2 print(AndrewFpstat2(psrs_full,Nmat_full,newtoas_full,f0_full))
#
# NameError: name 'GetRefTime' is not defined

# %%
newtoas_test = GetRefTime(psrs_test)
print(AndrewFpstat2(psrs_test,Nmat_test,newtoas_test,f0_test))
# Out:
# 3.1005477219201003

# %%
nfreqs = 1000
Tspan = Tspan_full
startfreq = 1/Tspan
endfreq = 3.3e-7

logfreqs = np.logspace(np.log10(startfreq),np.log10(endfreq),nfreqs)

linfreqs = np.arange(startfreq,endfreq,1/Tspan)
print(linfreqs[1]-linfreqs[0])

i = 1
#fstat_array_full = []
fstat_array_test = []
start = time.time()
for gwfreq in linfreqs:
    #fstat_array_full.append(AndrewFpstat2(psrs_full,Nmat_full,newtoas_full,gwfreq))
    fstat_array_test.append(AndrewFpstat2(psrs_test,Nmat_test,newtoas_test,gwfreq))
    if i % 50 == 0:
        end = time.time()
        print(repr(i) + ' Done. ' + ' Time Elapsed: ' + repr(end-start))
    i += 1
# Out:
# 3.421256282315104e-09
# 50 Done.  Time Elapsed: 14.35664701461792

# %%
plt.plot(linfreqs,fstat_array_test)
plt.xscale('log')
plt.ylabel(r'$\mathcal{F}_{p}$',fontsize = 'xx-large')
plt.xlabel(r'$f$ [Hz]',fontsize = 'xx-large')
plt.show()

# %%
dof_full = 2*len(psrs_full)
dof_test = 2*len(psrs_test)

x = np.linspace(0,12,nfreqs)

# %%
nbins = 50
#plt.hist(fstat_array,bins = nbins,density = True)
plt.hist(2*fstat_array_test,bins = nbins,density = True)
plt.plot(x,chi2.pdf(x,dof_test))
#plt.hist(fstat_array_test,bins = nbins,density = True)
plt.xlabel(r'$\mathcal{F}_{p}$',fontsize = 'xx-large')
plt.show()

# %%
nbins = 50
#plt.hist(fstat_array,bins = nbins,density = True)
plt.hist(fstat_array_full,bins = nbins,density = True)
#plt.hist(fstat_array_test,bins = nbins,density = True)
plt.xlabel(r'$\mathcal{F}_{p}$',fontsize = 'xx-large')
plt.show()

# %% [markdown]
# ########## TAKES FOREVER TO RUN, USE ANDREWFPSTAT2 AND GETNMATRIX #################
# def AndrewFestat(pta,psrs,f0,gwphi,gwtheta):
#     '''Takes in the full pta, the pulsars that make up the pta
#     (Should make this a function in ptas to use self instead of pta?),
#     the orbital frequency of the gravitational wave, phi (GW azimuthal angle in radians),
#     and theta (GW polar angle in radians).
#     Returns the Fe statistic
#     '''
#     params = pta.params #come up with a more clever way of doing this
#
#     TNrs = pta.get_TNr(params)
#     TNTs = pta.get_TNT(params)
#     phiinvs = pta.get_phiinv(params, logdet=False, method='partition')
#
#     #Get noise parameters for pta toaerr**2
#     Nvecs = pta.get_ndiag(params)
#     Ts = pta.get_basis(params)
#     Nmat = []
#
#     festat = 0.0
#
#     #Probably a better way of doing this as well, but using TNTs[ii] for example didn't work
#     for ii,p in enumerate(psrs):
#         phiinv, TNr, TNT, Nvec, T = phiinvs[ii], TNrs[ii], TNTs[ii], Nvecs[ii], Ts[ii]
#         Sigma = TNT + (np.diag(phiinv) if phiinv.ndim == 1 else phiinv)
#         cf = sl.cho_factor(Sigma)
#         #Put pulsar's autoerrors in a diagonal matrix
#         Ndiag = np.diag(1.0/Nvec)
#         Tt = np.transpose(T)
#         TtN = np.dot(Tt,Ndiag)
#         expval2 = sl.cho_solve(cf,TtN)
#         TtNt = np.transpose(TtN)
#
#         #An Ntoa by Ntoa noise matrix to be used in expand dense matrix calculations earlier
#         Nmat.append(Ndiag - np.dot(TtNt,expval2))
#
#         # define N vectors from Ellis et al, 2012 N_i=(x|A_i) for each pulsar
#         N = np.zeros(4)
#         # define M matrix M_ij=(A_i|A_j)
#         M = np.zeros((4,4))
#
#         fplus, fcross, cosMu = utils.create_gw_antenna_pattern(p.pos, gwtheta, gwphi)
#
#         # define A
#         A = np.zeros((4, len(p.toas)))
#         A[0,:] = fplus/f0**(1./3.) * np.sin(2*f0*p.toas)
#         A[1,:] = fplus/f0**(1./3.) * np.cos(2*f0*p.toas)
#         A[2,:] = fcross/f0**(1./3.) * np.sin(2*f0*p.toas)
#         A[3,:] = fcross/f0**(1./3.) * np.cos(2*f0*p.toas)
#
#
#         N += np.array([np.dot(A[0,:], np.dot(Nmat[ii],p.residuals)), \
#                     np.dot(A[1,:], np.dot(Nmat[ii],p.residuals)), \
#                     np.dot(A[2,:], np.dot(Nmat[ii],p.residuals)), \
#                     np.dot(A[3,:], np.dot(Nmat[ii],p.residuals))])
#
#         M += np.dot(A, np.dot(p.invCov, np.transpose(A)))
#
#         # take inverse of M
#         Minv = sl.pinv(M)
#
#         festat += 0.5 * np.dot(N, np.dot(Minv, N))
#
#     return festat

# %%
def AndrewFestat2(psrs,Nmat,aligned_toas,f0,gwphi,gwtheta):
    '''Takes in the pulsars that make up the pta, the Nmatrix from GetNmat 
    (Should make this a function in ptas to use self instead of pta?),
    the frequency of the gravitational wave, phi (GW azimuthal angle in radians), 
    and theta (GW polar angle in radians).
    Returns the Fe statistic
    '''
    festat = 0.0
    
    #Probably a better way of doing this as well, but using TNTs[ii] for example didn't work
    for ii,p in enumerate(psrs):
        # define N vectors from Ellis et al, 2012 N_i=(x|A_i) for each pulsar
        N = np.zeros(4)
        # define M matrix M_ij=(A_i|A_j)
        M = np.zeros((4,4))

        fplus, fcross, cosMu = utils.create_gw_antenna_pattern(p.pos, gwtheta, gwphi)

        # define A
        A = np.zeros((4, len(aligned_toas[ii])))
        A[0,:] = fplus/f0**(1./3.) * np.sin(2*np.pi*f0*aligned_toas[ii])
        A[1,:] = fplus/f0**(1./3.) * np.cos(2*np.pi*f0*aligned_toas[ii])
        A[2,:] = fcross/f0**(1./3.) * np.sin(2*np.pi*f0*aligned_toas[ii])
        A[3,:] = fcross/f0**(1./3.) * np.cos(2*np.pi*f0*aligned_toas[ii])

        N += np.array([np.dot(A[0,:], np.dot(Nmat[ii],p.residuals)), \
                    np.dot(A[1,:], np.dot(Nmat[ii],p.residuals)), \
                    np.dot(A[2,:], np.dot(Nmat[ii],p.residuals)), \
                    np.dot(A[3,:], np.dot(Nmat[ii],p.residuals))])
    
        # define M matrix M_ij=(A_i|A_j)
        M += np.dot(A, np.dot(Nmat[ii], A.T))
        
        
        # take inverse of M
        Minv = sl.pinv(M)
        
        festat += 0.5 * np.dot(N, np.dot(Minv, N))
        
    return festat

# %%
gwtheta = 30/180*np.pi
gwphi = 10/180*np.pi
print(AndrewFestat2(psrs_full,Nmat_full,newtoas_full,f0_full,gwtheta,gwphi))
# Out:
# 64.05763009275555

# %%
nfreqs = 1000
Tspan = Tspan_full
freqs = np.logspace(np.log10(1/Tspan),np.log10(3.3e-7),nfreqs)

i = 1
festat_array_full = []
festat_array_test = []
start = time.time()
for gwfreq in freqs:
    festat_array_full.append(AndrewFestat2(psrs_full,Nmat_full,newtoas_full,gwfreq,gwtheta,gwphi))
    #festat_array_test.append(AndrewFestat2(psrs_test,Nmat_test,newtoas_test,gwfreq,gwtheta,gwphi))
    if i % 50 == 0:
        end = time.time()
        print(repr(i) + ' Done. ' + ' Time Elapsed: ' + repr(end-start))
    i += 1
# Out:
# 50 Done.  Time Elapsed: 26.16207480430603
# 100 Done.  Time Elapsed: 37.18350291252136
# 150 Done.  Time Elapsed: 48.23997259140015
# 200 Done.  Time Elapsed: 59.172839879989624
# 250 Done.  Time Elapsed: 70.01483368873596
# 300 Done.  Time Elapsed: 80.89029455184937
# 350 Done.  Time Elapsed: 91.98427629470825
# 400 Done.  Time Elapsed: 102.833913564682
# 450 Done.  Time Elapsed: 113.77218413352966
# 500 Done.  Time Elapsed: 124.79858422279358
# 550 Done.  Time Elapsed: 135.7897868156433
# 600 Done.  Time Elapsed: 146.98360323905945
# 650 Done.  Time Elapsed: 158.07582998275757
# 700 Done.  Time Elapsed: 168.91558456420898
# 750 Done.  Time Elapsed: 180.00105547904968
# 800 Done.  Time Elapsed: 191.10464358329773
# 850 Done.  Time Elapsed: 202.17362093925476
# 900 Done.  Time Elapsed: 213.30400681495667
# 950 Done.  Time Elapsed: 224.67976140975952
# 1000 Done.  Time Elapsed: 236.01119923591614

# %%
nbins = 50
#plt.hist(fstat_array,bins = nbins,density = True)
plt.hist(festat_array_test,bins = nbins,density = True)
#plt.hist(fstat_array_test,bins = nbins,density = True)
plt.xlabel(r'$\mathcal{F}_{e}$',fontsize = 'xx-large')
plt.show()
